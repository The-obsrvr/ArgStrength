# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Siddharth\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Single Task Data

# %%
eval_results = pd.read_csv("evaluation_results.csv", sep=",")
results = eval_results[eval_results["task_id"].str.contains("MTLAS")==False]

# %%
def prepare_single_task(single_task_data: pd.DataFrame):
    """

    :param single_task_data:
    :return:
    """
    single_task_data["use_topic"] = single_task_data["task_id"].str.contains("_topic")
    d = {True: 'topic', False: 'no-topic'}
    results = single_task_data.replace(d)

    datasets = ['gretz', 'swanson', 'ukp', 'webis', 'toledo']
    aggregated_cols = [col for col in results.columns if any(s in col for s in datasets)]

    #  aggregate over the seeds.
    results_by_task = results.groupby(["task_id", "sampling", "use_topic"], as_index=False).agg(
        {
            d: ['mean', 'std']
            for d in aggregated_cols
        }).round(3)

    # extract the values from the hierarchical dataframe.
    task_details = results_by_task.loc[:, (slice(None), '')]
    task_details.columns = task_details.columns.get_level_values(0)

    means = results_by_task.loc[:, (slice(None), 'mean')]
    means.columns = means.columns.get_level_values(0)

    stds = results_by_task.loc[:, (slice(None), 'std')]
    stds.columns = stds.columns.get_level_values(0)

    #  separate pearson and spearman
    pearson_means = means.filter(regex='pearson')
    pearson_stds = stds.filter(regex='pearson')
    pearson_stds.columns = "d_" + pearson_stds.columns
    pearson_data = pd.concat([task_details, pearson_means, pearson_stds], axis=1)

    spearman_means = means.filter(regex='spearman')
    spearman_stds = stds.filter(regex='spearman')
    spearman_stds.columns = "d_" + spearman_stds.columns
    spearman_data = pd.concat([task_details, spearman_means, spearman_stds], axis=1)

    #  combine the mean and std values for the pearson coefficients.
    if "gretz_pearson" in pearson_data.columns:
        pearson_data["IBMArgQ"] = [
            "$\rho: " + str(pearson_data["gretz_pearson"][i]) + " \pm " + str(
                pearson_data["d_gretz_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["IBMArgQ"] = [
            "$\sigma: " + str(spearman_data["gretz_spearman"][i]) + " \pm " + str(
                spearman_data["d_gretz_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["IBMArgQ"] = None
        spearman_data["IBMArgQ"] = None

    if "toledo_pearson" in pearson_data.columns:
        pearson_data["IBMRank"] = [
            "$\rho: " + str(pearson_data["toledo_pearson"][i]) + " \pm " + str(
                pearson_data["d_toledo_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["IBMRank"] = [
            "$\sigma: " + str(spearman_data["toledo_spearman"][i]) + " \pm " + str(
                spearman_data["d_toledo_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["IBMRank"] = None
        spearman_data["IBMRank"] = None

    if "ukp_pearson" in pearson_data.columns:
        pearson_data["UKPConvArgRank"] = [
            "$\rho: " + str(pearson_data["ukp_pearson"][i]) + " \pm " + str(
                pearson_data["d_ukp_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["UKPConvArgRank"] = [
            "$\sigma: " + str(spearman_data["ukp_spearman"][i]) + " \pm " + str(
                spearman_data["d_ukp_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["UKPConvArgRank"] = None
        spearman_data["UKPConvArgRank"] = None

    if "swanson_pearson" in pearson_data.columns:
        pearson_data["SwanRank"] = [
            "$\rho: " + str(pearson_data["swanson_pearson"][i]) + " \pm " + str(
                pearson_data["d_swanson_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["SwanRank"] = [
            "$\sigma: " + str(spearman_data["swanson_spearman"][i]) + " \pm " + str(
                spearman_data["d_swanson_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["SwanRank"] = None
        spearman_data["SwanRank"] = None

    if "webis_pearson" in pearson_data.columns:
        pearson_data["Webis"] = [
            "$\rho: " + str(pearson_data["webis_pearson"][i]) + " \pm " + str(
                pearson_data["d_webis_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["Webis"] = [
            "$\sigma: " + str(spearman_data["webis_spearman"][i]) + " \pm " + str(
                spearman_data["d_webis_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["Webis"] = None
        spearman_data["Webis"] = None

    final_pearson = pearson_data[
        ["task_id", "sampling", "use_topic", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]
    final_spearman = spearman_data[
        ["task_id", "sampling", "use_topic", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]

    metrics_table = pd.concat([final_pearson, final_spearman]).sort_values(by=["task_id", "sampling", "use_topic"])

    # rename task_id to proper names.
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_gretz") is True] = "IBMArgQ"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_toledo") is True] = "IBMRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_ukp") is True] = "UKPConvArgRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_swanson") is True] = "SwanRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_webis") is True] = "Webis"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_gretz") is True] = "All except IBMArgQ"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_toledo") is True] = "All except IBMRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_ukp") is True] = \
        "All except UKPConvArgRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_swanson") is True] = "All except SwanRank"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_webis") is True] = "All except Webis"
    metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS") is True] = "All"

    metrics_table.sort_values(by=["task_id", "sampling", "use_topic"], inplace=True)
    #  Define the latex table structure.
    col1 = metrics_table["task_id"].tolist()
    col2 = metrics_table["sampling"].tolist()
    col3 = metrics_table["use_topic"].tolist()
    cidx = ["IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]
    iidx = pd.MultiIndex.from_arrays([
        col1, col2, col3
    ])
    metrics_value_table = metrics_table.iloc[:, 3:]
    values_list = metrics_value_table.values.tolist()
    latex_table = pd.DataFrame(
        values_list, columns=cidx, index=iidx)
    pd.options.display.float_format = '{:,.3f}'.format
    ltx_code = latex_table.to_latex(
        caption="Single Task Learning",
        header=cidx,
        position="H",
        escape=False,
        multirow=True,
        column_format="|lll|lllll|",
    )
    print(ltx_code)
    return ltx_code

# %%
prepare_single_task(results)
# Out:
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1061         try:
# -> 1062             self._set_with_engine(key, value)
#    1063         except (KeyError, ValueError):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1094         # fails with AttributeError for IntervalIndex
# -> 1095         loc = self.index._engine.get_loc(key)
#    1096         # error: Argument 1 to "validate_numeric_casting" has incompatible type
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d4d97360c982> in <module>
# ----> 1 prepare_single_task(results)
#
# <ipython-input-19-c1d89b363bad> in prepare_single_task(single_task_data)
#     114
#     115     # rename task_id to proper names.
# --> 116     metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_gretz") is True] = "IBMArgQ"
#     117     metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_toledo") is True] = "IBMRank"
#     118     metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_ukp") is True] = "UKPConvArgRank"
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1068             else:
#    1069                 # GH#12862 adding a new key to the Series
# -> 1070                 self.loc[key] = value
#    1071
#    1072         except TypeError as err:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1719         else:
#    1720
# -> 1721             indexer, missing = convert_missing_indexer(indexer)
#    1722
#    1723             if missing:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in convert_missing_indexer(indexer)
#    2413
#    2414         if isinstance(indexer, bool):
# -> 2415             raise KeyError("cannot use a single bool to index into setitem")
#    2416         return indexer, True
#    2417
#
# KeyError: 'cannot use a single bool to index into setitem'

# %%
# Define topic information
results["use_topic"] = results["task_id"].str.contains("_topic")
d = {True: 'topic', False: 'no-topic'}
results = results.replace(d)
# Out:
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
results.head()
# Out:
#               task_id  sampling  \
# 0   STLAS_only_toledo  in-topic
# 1  STLAS_only_swanson  in-topic
# 2    STLAS_only_gretz  in-topic
# 3      STLAS_only_ukp  in-topic
# 4   STLAS_only_toledo  in-topic
#
#                                           checkpoint  test_overall_pearson  \
# 0  experiments/version_24-02-2022--10-34-07/check...                0.4001
# 1  experiments/version_24-02-2022--10-32-00/check...                0.3150
# 2  experiments/version_24-02-2022--10-26-29/check...                0.5007
# 3  experiments/version_24-02-2022--10-36-24/check...                0.0585
# 4  experiments/version_24-02-2022--10-38-16/check...                0.4102
#
#    gretz_pearson  gretz_spearman  swanson_pearson  swanson_spearman  \
# 0         0.4105          0.3909           0.3103            0.3372
# 1         0.2289          0.1655           0.6374            0.6081
# 2         0.5030          0.4449           0.4549            0.4928
# 3         0.0165         -0.0004           0.4435            0.3869
# 4         0.4195          0.3903           0.3246            0.3495
#
#    toledo_pearson  toledo_spearman  ukp_pearson  ukp_spearman  webis_pearson  \
# 0          0.4993           0.4798       0.2575        0.3696         0.1977
# 1          0.3135           0.2173       0.5696        0.4718         0.5405
# 2          0.4360           0.4132       0.4345        0.4840         0.4265
# 3         -0.1760          -0.2124       0.3942        0.3013         0.5411
# 4          0.5001           0.4773       0.3158        0.3950         0.3062
#
#    webis_spearman  test_loss use_topic
# 0          0.2096     0.0726  no-topic
# 1          0.5476     0.0449  no-topic
# 2          0.3523     0.0355  no-topic
# 3          0.4703     0.0635  no-topic
# 4          0.3179     0.0691  no-topic

# %%
results_by_task = results.groupby(["task_id", "sampling", "use_topic"], as_index=False).agg(
                        {
                        'gretz_pearson': ['mean', 'std'],
                        'toledo_pearson': ['mean', 'std'],
                        'ukp_pearson': ['mean', 'std'],
                        'swanson_pearson': ['mean', 'std'],
                        'webis_pearson': ['mean', 'std'], 
                        'gretz_spearman': ['mean', 'std'],
                        'toledo_spearman': ['mean', 'std'],
                        'ukp_spearman': ['mean', 'std'],
                        'swanson_spearman': ['mean', 'std'],
                        'webis_spearman': ['mean', 'std'],
                        }).round(3)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(results_by_task.sort_values(by=["task_id", "sampling"]))
# Out:
#                      task_id     sampling use_topic gretz_pearson         \
#                                                              mean    std
# 0                      MTLAS  cross-topic     False         0.495  0.015
# 1                      MTLAS     in-topic     False         0.511  0.004
# 2                MTLAS_topic  cross-topic      True         0.482  0.014
# 3                MTLAS_topic     in-topic      True         0.515  0.004
# 4                      STLAS  cross-topic     False         0.427  0.030
# 5                      STLAS     in-topic     False         0.403  0.004
# 6            STLAS_LOO_gretz  cross-topic     False         0.256  0.068
# 7            STLAS_LOO_gretz     in-topic     False         0.242  0.012
# 8      STLAS_LOO_gretz_topic  cross-topic      True         0.303  0.030
# 9      STLAS_LOO_gretz_topic     in-topic      True         0.359  0.012
# 10         STLAS_LOO_swanson  cross-topic     False         0.429  0.029
# 11         STLAS_LOO_swanson     in-topic     False         0.405  0.006
# 12   STLAS_LOO_swanson_topic  cross-topic      True         0.473  0.009
# 13   STLAS_LOO_swanson_topic     in-topic      True         0.509  0.007
# 14          STLAS_LOO_toledo  cross-topic     False         0.465  0.015
# 15          STLAS_LOO_toledo     in-topic     False         0.462  0.022
# 16    STLAS_LOO_toledo_topic  cross-topic      True         0.482  0.015
# 17    STLAS_LOO_toledo_topic     in-topic      True         0.502  0.005
# 18             STLAS_LOO_ukp  cross-topic     False         0.439  0.022
# 19             STLAS_LOO_ukp     in-topic     False         0.412  0.011
# 20       STLAS_LOO_ukp_topic  cross-topic      True         0.475  0.009
# 21       STLAS_LOO_ukp_topic     in-topic      True         0.513  0.006
# 22           STLAS_LOO_webis  cross-topic     False         0.442  0.023
# 23           STLAS_LOO_webis     in-topic     False         0.418  0.009
# 24     STLAS_LOO_webis_topic  cross-topic      True         0.469  0.016
# 25     STLAS_LOO_webis_topic     in-topic      True         0.414  0.007
# 26          STLAS_only_gretz  cross-topic     False         0.490  0.013
# 27          STLAS_only_gretz     in-topic     False         0.504  0.002
# 28    STLAS_only_gretz_topic  cross-topic      True         0.474  0.019
# 29    STLAS_only_gretz_topic     in-topic      True         0.511  0.004
# 30        STLAS_only_swanson  cross-topic     False         0.218  0.034
# 31        STLAS_only_swanson     in-topic     False         0.228  0.006
# 32  STLAS_only_swanson_topic  cross-topic      True         0.110  0.048
# 33  STLAS_only_swanson_topic     in-topic      True         0.108  0.048
# 34         STLAS_only_toledo  cross-topic     False         0.373  0.032
# 35         STLAS_only_toledo     in-topic     False         0.415  0.004
# 36   STLAS_only_toledo_topic  cross-topic      True         0.324  0.043
# 37   STLAS_only_toledo_topic     in-topic      True         0.394  0.006
# 38            STLAS_only_ukp  cross-topic     False         0.058  0.057
# 39            STLAS_only_ukp     in-topic     False         0.102  0.051
# 40      STLAS_only_ukp_topic  cross-topic      True         0.048  0.044
# 41      STLAS_only_ukp_topic     in-topic      True         0.077  0.057
# 42          STLAS_only_webis  cross-topic     False         0.214  0.034
# 43          STLAS_only_webis     in-topic     False         0.257  0.010
# 44    STLAS_only_webis_topic  cross-topic      True         0.214  0.034
# 45    STLAS_only_webis_topic     in-topic      True         0.257  0.010
# 46               STLAS_topic  cross-topic      True         0.477  0.012
# 47               STLAS_topic     in-topic      True         0.496  0.006
#
#    toledo_pearson        ukp_pearson        swanson_pearson         \
#              mean    std        mean    std            mean    std
# 0           0.440  0.064       0.416  0.110           0.505  0.132
# 1           0.520  0.012       0.600  0.034           0.660  0.006
# 2           0.429  0.072       0.434  0.096           0.494  0.141
# 3           0.535  0.007       0.654  0.042           0.679  0.005
# 4           0.401  0.049       0.228  0.097           0.461  0.086
# 5           0.356  0.010       0.410  0.016           0.643  0.007
# 6           0.318  0.053       0.102  0.081           0.396  0.123
# 7           0.441  0.012       0.363  0.015           0.622  0.007
# 8           0.374  0.068       0.259  0.046           0.452  0.132
# 9           0.528  0.007       0.328  0.010           0.675  0.009
# 10          0.393  0.050       0.177  0.081           0.346  0.058
# 11          0.345  0.008       0.328  0.027           0.493  0.018
# 12          0.303  0.137       0.204  0.056           0.285  0.067
# 13          0.533  0.003       0.264  0.109           0.366  0.024
# 14          0.419  0.048       0.234  0.102           0.453  0.111
# 15          0.411  0.020       0.442  0.019           0.647  0.016
# 16          0.330  0.083       0.390  0.044           0.441  0.137
# 17          0.375  0.017       0.468  0.021           0.666  0.007
# 18          0.409  0.049       0.285  0.058           0.446  0.095
# 19          0.373  0.010       0.580  0.023           0.607  0.012
# 20          0.338  0.085       0.410  0.056           0.462  0.149
# 21          0.536  0.003       0.531  0.027           0.659  0.008
# 22          0.393  0.061       0.293  0.087           0.470  0.107
# 23          0.339  0.011       0.467  0.015           0.651  0.005
# 24          0.400  0.055       0.257  0.090           0.452  0.132
# 25          0.331  0.010       0.484  0.007           0.654  0.010
# 26          0.434  0.052       0.396  0.074           0.392  0.111
# 27          0.439  0.004       0.444  0.035           0.466  0.010
# 28          0.424  0.051       0.402  0.090           0.337  0.119
# 29          0.456  0.010       0.441  0.018           0.381  0.020
# 30          0.241  0.034       0.350  0.100           0.462  0.100
# 31          0.295  0.012       0.550  0.013           0.647  0.007
# 32          0.163  0.060       0.307  0.092           0.465  0.128
# 33          0.205  0.032       0.418  0.037           0.677  0.005
# 34          0.384  0.082       0.287  0.104           0.326  0.075
# 35          0.504  0.005       0.293  0.035           0.318  0.035
# 36          0.341  0.091       0.338  0.104           0.311  0.087
# 37          0.515  0.014       0.335  0.030           0.280  0.028
# 38         -0.068  0.062       0.267  0.148           0.303  0.090
# 39         -0.040  0.086       0.384  0.051           0.450  0.028
# 40         -0.045  0.122       0.131  0.062           0.316  0.112
# 41         -0.081  0.065       0.149  0.092           0.419  0.053
# 42          0.213  0.063       0.264  0.063           0.251  0.105
# 43          0.240  0.032       0.394  0.029           0.329  0.043
# 44          0.213  0.063       0.264  0.063           0.251  0.105
# 45          0.239  0.032       0.394  0.029           0.329  0.043
# 46          0.410  0.075       0.273  0.062           0.436  0.112
# 47          0.522  0.018       0.329  0.032           0.670  0.008
#
#    webis_pearson        gretz_spearman        toledo_spearman         \
#             mean    std           mean    std            mean    std
# 0          0.790  0.047          0.439  0.014           0.421  0.058
# 1          0.559  0.021          0.457  0.004           0.501  0.014
# 2          0.786  0.049          0.422  0.010           0.407  0.069
# 3          0.598  0.016          0.463  0.004           0.508  0.009
# 4          0.500  0.094          0.368  0.028           0.390  0.043
# 5          0.493  0.016          0.335  0.003           0.334  0.012
# 6          0.349  0.106          0.205  0.061           0.293  0.052
# 7          0.500  0.011          0.191  0.009           0.419  0.016
# 8          0.750  0.065          0.269  0.031           0.353  0.063
# 9          0.605  0.021          0.329  0.011           0.505  0.012
# 10         0.385  0.091          0.372  0.026           0.381  0.047
# 11         0.441  0.015          0.336  0.007           0.331  0.009
# 12         0.763  0.063          0.421  0.014           0.298  0.134
# 13         0.570  0.031          0.451  0.010           0.506  0.008
# 14         0.404  0.113          0.410  0.010           0.417  0.045
# 15         0.460  0.019          0.413  0.016           0.402  0.014
# 16         0.735  0.047          0.429  0.012           0.352  0.057
# 17         0.635  0.065          0.449  0.006           0.278  0.030
# 18         0.378  0.083          0.378  0.020           0.392  0.044
# 19         0.481  0.026          0.344  0.012           0.346  0.014
# 20         0.758  0.050          0.425  0.015           0.318  0.081
# 21         0.613  0.014          0.458  0.008           0.506  0.006
# 22         0.677  0.054          0.380  0.014           0.384  0.057
# 23         0.643  0.027          0.350  0.009           0.316  0.017
# 24         0.619  0.077          0.413  0.013           0.390  0.050
# 25         0.530  0.024          0.347  0.006           0.310  0.012
# 26         0.577  0.091          0.434  0.009           0.435  0.045
# 27         0.445  0.021          0.447  0.003           0.416  0.003
# 28         0.586  0.075          0.417  0.014           0.419  0.042
# 29         0.325  0.045          0.456  0.005           0.406  0.011
# 30         0.547  0.222          0.154  0.024           0.166  0.044
# 31         0.548  0.019          0.159  0.005           0.189  0.019
# 32         0.443  0.195          0.067  0.043           0.101  0.071
# 33         0.381  0.039          0.082  0.040           0.069  0.036
# 34         0.276  0.202          0.348  0.028           0.366  0.072
# 35         0.249  0.053          0.389  0.003           0.477  0.004
# 36         0.349  0.225          0.303  0.038           0.324  0.086
# 37         0.213  0.071          0.377  0.005           0.486  0.017
# 38         0.543  0.066          0.036  0.052          -0.097  0.058
# 39         0.512  0.027          0.080  0.047          -0.080  0.084
# 40         0.519  0.131          0.029  0.039          -0.054  0.132
# 41         0.483  0.038          0.065  0.052          -0.063  0.075
# 42         0.494  0.080          0.214  0.031           0.225  0.064
# 43         0.396  0.025          0.258  0.006           0.220  0.031
# 44         0.494  0.080          0.214  0.031           0.225  0.064
# 45         0.396  0.025          0.258  0.006           0.220  0.031
# 46         0.727  0.053          0.420  0.010           0.394  0.067
# 47         0.601  0.020          0.440  0.009           0.497  0.019
#
#    ukp_spearman        swanson_spearman        webis_spearman
#            mean    std             mean    std           mean    std
# 0         0.499  0.145            0.492  0.145          0.794  0.051
# 1         0.565  0.043            0.633  0.006          0.593  0.029
# 2         0.502  0.165            0.484  0.153          0.791  0.044
# 3         0.646  0.035            0.653  0.005          0.650  0.013
# 4         0.302  0.040            0.450  0.096          0.360  0.114
# 5         0.424  0.015            0.617  0.009          0.492  0.014
# 6         0.146  0.050            0.385  0.126          0.283  0.115
# 7         0.485  0.037            0.584  0.005          0.534  0.013
# 8         0.306  0.201            0.445  0.139          0.765  0.063
# 9         0.460  0.057            0.653  0.010          0.678  0.016
# 10        0.223  0.087            0.339  0.059          0.317  0.109
# 11        0.416  0.023            0.472  0.022          0.462  0.013
# 12        0.144  0.171            0.295  0.066          0.787  0.042
# 13        0.380  0.055            0.397  0.032          0.678  0.027
# 14        0.341  0.019            0.441  0.121          0.306  0.119
# 15        0.436  0.018            0.625  0.015          0.450  0.026
# 16        0.378  0.122            0.440  0.138          0.746  0.048
# 17        0.531  0.086            0.640  0.008          0.690  0.062
# 18        0.317  0.061            0.432  0.109          0.335  0.101
# 19        0.543  0.027            0.572  0.011          0.497  0.028
# 20        0.583  0.067            0.462  0.150          0.772  0.043
# 21        0.692  0.015            0.632  0.010          0.676  0.015
# 22        0.425  0.081            0.462  0.116          0.628  0.066
# 23        0.421  0.025            0.630  0.007          0.722  0.028
# 24        0.330  0.072            0.446  0.139          0.547  0.099
# 25        0.456  0.017            0.631  0.009          0.549  0.014
# 26        0.506  0.069            0.390  0.113          0.512  0.096
# 27        0.487  0.006            0.496  0.009          0.383  0.031
# 28        0.511  0.077            0.347  0.110          0.546  0.091
# 29        0.559  0.014            0.432  0.031          0.337  0.051
# 30        0.394  0.114            0.450  0.111          0.511  0.205
# 31        0.468  0.025            0.616  0.005          0.539  0.015
# 32        0.277  0.137            0.450  0.138          0.365  0.169
# 33        0.458  0.050            0.651  0.008          0.360  0.055
# 34        0.355  0.140            0.329  0.076          0.328  0.204
# 35        0.390  0.016            0.338  0.040          0.268  0.052
# 36        0.406  0.168            0.310  0.084          0.389  0.232
# 37        0.484  0.071            0.315  0.037          0.226  0.090
# 38        0.315  0.206            0.305  0.087          0.445  0.079
# 39        0.302  0.020            0.410  0.030          0.460  0.023
# 40        0.108  0.197            0.308  0.117          0.417  0.134
# 41        0.009  0.112            0.367  0.055          0.477  0.073
# 42        0.324  0.114            0.242  0.108          0.528  0.097
# 43        0.513  0.049            0.373  0.047          0.465  0.037
# 44        0.324  0.114            0.242  0.108          0.528  0.097
# 45        0.512  0.048            0.373  0.047          0.464  0.036
# 46        0.338  0.149            0.432  0.114          0.748  0.051
# 47        0.318  0.083            0.645  0.012          0.674  0.016

# %%
metrics_table = pd.concat([final_pearson, final_spearman]).sort_values(by=["task_id", "sampling", "use_topic"])

# %%
metrics_table.head()
# Out:
#        task_id     sampling use_topic                    IBMArgQ  \
# 0        MTLAS  cross-topic  no-topic    $\rho: 0.495 \pm 0.015$
# 0        MTLAS  cross-topic  no-topic  $\sigma: 0.439 \pm 0.014$
# 1        MTLAS     in-topic  no-topic    $\rho: 0.511 \pm 0.004$
# 1        MTLAS     in-topic  no-topic  $\sigma: 0.457 \pm 0.004$
# 2  MTLAS_topic  cross-topic     topic    $\rho: 0.482 \pm 0.014$
#
#                      IBMRank             UKPConvArgRank  \
# 0     $\rho: 0.44 \pm 0.064$     $\rho: 0.416 \pm 0.11$
# 0  $\sigma: 0.421 \pm 0.058$  $\sigma: 0.499 \pm 0.145$
# 1     $\rho: 0.52 \pm 0.012$      $\rho: 0.6 \pm 0.034$
# 1  $\sigma: 0.501 \pm 0.014$  $\sigma: 0.565 \pm 0.043$
# 2    $\rho: 0.429 \pm 0.072$    $\rho: 0.434 \pm 0.096$
#
#                     SwanRank                      Webis
# 0    $\rho: 0.505 \pm 0.132$     $\rho: 0.79 \pm 0.047$
# 0  $\sigma: 0.492 \pm 0.145$  $\sigma: 0.794 \pm 0.051$
# 1     $\rho: 0.66 \pm 0.006$    $\rho: 0.559 \pm 0.021$
# 1  $\sigma: 0.633 \pm 0.006$  $\sigma: 0.593 \pm 0.029$
# 2    $\rho: 0.494 \pm 0.141$    $\rho: 0.786 \pm 0.049$

# %%
# rename task_id to proper names.
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_gretz")==True] = "IBMArgQ"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_toledo")==True] = "IBMRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_ukp")==True] = "UKPConvArgRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_swanson")==True] = "SwanRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_only_webis")==True] = "Webis"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_gretz")==True] = "All except IBMArgQ"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_toledo")==True] = "All except IBMRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_ukp")==True] = "All except UKPConvArgRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_swanson")==True] = "All except SwanRank"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS_LOO_webis")==True] = "All except Webis"
metrics_table["task_id"][metrics_table["task_id"].str.contains("STLAS")==True] = "All"

# %%
col1 = metrics_table["task_id"].tolist()
col2 = metrics_table["sampling"].tolist()
col3 = metrics_table["use_topic"].tolist()
cidx = ["IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]
iidx = pd.MultiIndex.from_arrays([
    col1, col2, col3
])
metrics_value_table = metrics_table.iloc[:, 3:]
values_list = metrics_value_table.values.tolist()

# %%
latex_table = pd.DataFrame(
    values_list, columns=cidx, index=iidx)

# %%
pd.options.display.float_format = '{:,.3f}'.format
ltx_code = latex_table.to_latex(
    caption="Single Task Learning",
    position="H",
    escape=False,
    multirow=True,
)

# %%
print(ltx_code)
# Out:
# \begin{table}[H]
# \centering
# \caption{Single Task Learning}
# \begin{tabular}{llllllll}
# \toprule
#     &          &       &                    IBMArgQ &                     IBMRank &             UKPConvArgRank &                   SwanRank &                      Webis \\
# \midrule
# \multirow{8}{*}{MTLAS} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.495 \pm 0.015$ &      $\rho: 0.44 \pm 0.064$ &     $\rho: 0.416 \pm 0.11$ &    $\rho: 0.505 \pm 0.132$ &     $\rho: 0.79 \pm 0.047$ \\
#     &          & no-topic &  $\sigma: 0.439 \pm 0.014$ &   $\sigma: 0.421 \pm 0.058$ &  $\sigma: 0.499 \pm 0.145$ &  $\sigma: 0.492 \pm 0.145$ &  $\sigma: 0.794 \pm 0.051$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.511 \pm 0.004$ &      $\rho: 0.52 \pm 0.012$ &      $\rho: 0.6 \pm 0.034$ &     $\rho: 0.66 \pm 0.006$ &    $\rho: 0.559 \pm 0.021$ \\
#     &          & no-topic &  $\sigma: 0.457 \pm 0.004$ &   $\sigma: 0.501 \pm 0.014$ &  $\sigma: 0.565 \pm 0.043$ &  $\sigma: 0.633 \pm 0.006$ &  $\sigma: 0.593 \pm 0.029$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.482 \pm 0.014$ &     $\rho: 0.429 \pm 0.072$ &    $\rho: 0.434 \pm 0.096$ &    $\rho: 0.494 \pm 0.141$ &    $\rho: 0.786 \pm 0.049$ \\
#     &          & topic &   $\sigma: 0.422 \pm 0.01$ &   $\sigma: 0.407 \pm 0.069$ &  $\sigma: 0.502 \pm 0.165$ &  $\sigma: 0.484 \pm 0.153$ &  $\sigma: 0.791 \pm 0.044$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.515 \pm 0.004$ &     $\rho: 0.535 \pm 0.007$ &    $\rho: 0.654 \pm 0.042$ &    $\rho: 0.679 \pm 0.005$ &    $\rho: 0.598 \pm 0.016$ \\
#     &          & topic &  $\sigma: 0.463 \pm 0.004$ &   $\sigma: 0.508 \pm 0.009$ &  $\sigma: 0.646 \pm 0.035$ &  $\sigma: 0.653 \pm 0.005$ &   $\sigma: 0.65 \pm 0.013$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{4}{*}{All} & \multirow{2}{*}{cross-topic} & no-topic &     $\rho: 0.427 \pm 0.03$ &     $\rho: 0.401 \pm 0.049$ &    $\rho: 0.228 \pm 0.097$ &    $\rho: 0.461 \pm 0.086$ &      $\rho: 0.5 \pm 0.094$ \\
#     &          & no-topic &  $\sigma: 0.368 \pm 0.028$ &    $\sigma: 0.39 \pm 0.043$ &   $\sigma: 0.302 \pm 0.04$ &   $\sigma: 0.45 \pm 0.096$ &   $\sigma: 0.36 \pm 0.114$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.403 \pm 0.004$ &      $\rho: 0.356 \pm 0.01$ &     $\rho: 0.41 \pm 0.016$ &    $\rho: 0.643 \pm 0.007$ &    $\rho: 0.493 \pm 0.016$ \\
#     &          & no-topic &  $\sigma: 0.335 \pm 0.003$ &   $\sigma: 0.334 \pm 0.012$ &  $\sigma: 0.424 \pm 0.015$ &  $\sigma: 0.617 \pm 0.009$ &  $\sigma: 0.492 \pm 0.014$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{All except IBMArgQ} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.256 \pm 0.068$ &     $\rho: 0.318 \pm 0.053$ &    $\rho: 0.102 \pm 0.081$ &    $\rho: 0.396 \pm 0.123$ &    $\rho: 0.349 \pm 0.106$ \\
#     &          & no-topic &  $\sigma: 0.205 \pm 0.061$ &   $\sigma: 0.293 \pm 0.052$ &   $\sigma: 0.146 \pm 0.05$ &  $\sigma: 0.385 \pm 0.126$ &  $\sigma: 0.283 \pm 0.115$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.242 \pm 0.012$ &     $\rho: 0.441 \pm 0.012$ &    $\rho: 0.363 \pm 0.015$ &    $\rho: 0.622 \pm 0.007$ &      $\rho: 0.5 \pm 0.011$ \\
#     &          & no-topic &  $\sigma: 0.191 \pm 0.009$ &   $\sigma: 0.419 \pm 0.016$ &  $\sigma: 0.485 \pm 0.037$ &  $\sigma: 0.584 \pm 0.005$ &  $\sigma: 0.534 \pm 0.013$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &     $\rho: 0.303 \pm 0.03$ &     $\rho: 0.374 \pm 0.068$ &    $\rho: 0.259 \pm 0.046$ &    $\rho: 0.452 \pm 0.132$ &     $\rho: 0.75 \pm 0.065$ \\
#     &          & topic &  $\sigma: 0.269 \pm 0.031$ &   $\sigma: 0.353 \pm 0.063$ &  $\sigma: 0.306 \pm 0.201$ &  $\sigma: 0.445 \pm 0.139$ &  $\sigma: 0.765 \pm 0.063$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.359 \pm 0.012$ &     $\rho: 0.528 \pm 0.007$ &     $\rho: 0.328 \pm 0.01$ &    $\rho: 0.675 \pm 0.009$ &    $\rho: 0.605 \pm 0.021$ \\
#     &          & topic &  $\sigma: 0.329 \pm 0.011$ &   $\sigma: 0.505 \pm 0.012$ &   $\sigma: 0.46 \pm 0.057$ &   $\sigma: 0.653 \pm 0.01$ &  $\sigma: 0.678 \pm 0.016$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{All except SwanRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.429 \pm 0.029$ &      $\rho: 0.393 \pm 0.05$ &    $\rho: 0.177 \pm 0.081$ &    $\rho: 0.346 \pm 0.058$ &    $\rho: 0.385 \pm 0.091$ \\
#     &          & no-topic &  $\sigma: 0.372 \pm 0.026$ &   $\sigma: 0.381 \pm 0.047$ &  $\sigma: 0.223 \pm 0.087$ &  $\sigma: 0.339 \pm 0.059$ &  $\sigma: 0.317 \pm 0.109$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.405 \pm 0.006$ &     $\rho: 0.345 \pm 0.008$ &    $\rho: 0.328 \pm 0.027$ &    $\rho: 0.493 \pm 0.018$ &    $\rho: 0.441 \pm 0.015$ \\
#     &          & no-topic &  $\sigma: 0.336 \pm 0.007$ &   $\sigma: 0.331 \pm 0.009$ &  $\sigma: 0.416 \pm 0.023$ &  $\sigma: 0.472 \pm 0.022$ &  $\sigma: 0.462 \pm 0.013$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.473 \pm 0.009$ &     $\rho: 0.303 \pm 0.137$ &    $\rho: 0.204 \pm 0.056$ &    $\rho: 0.285 \pm 0.067$ &    $\rho: 0.763 \pm 0.063$ \\
#     &          & topic &  $\sigma: 0.421 \pm 0.014$ &   $\sigma: 0.298 \pm 0.134$ &  $\sigma: 0.144 \pm 0.171$ &  $\sigma: 0.295 \pm 0.066$ &  $\sigma: 0.787 \pm 0.042$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.509 \pm 0.007$ &     $\rho: 0.533 \pm 0.003$ &    $\rho: 0.264 \pm 0.109$ &    $\rho: 0.366 \pm 0.024$ &     $\rho: 0.57 \pm 0.031$ \\
#     &          & topic &   $\sigma: 0.451 \pm 0.01$ &   $\sigma: 0.506 \pm 0.008$ &   $\sigma: 0.38 \pm 0.055$ &  $\sigma: 0.397 \pm 0.032$ &  $\sigma: 0.678 \pm 0.027$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{All except IBMRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.465 \pm 0.015$ &     $\rho: 0.419 \pm 0.048$ &    $\rho: 0.234 \pm 0.102$ &    $\rho: 0.453 \pm 0.111$ &    $\rho: 0.404 \pm 0.113$ \\
#     &          & no-topic &    $\sigma: 0.41 \pm 0.01$ &   $\sigma: 0.417 \pm 0.045$ &  $\sigma: 0.341 \pm 0.019$ &  $\sigma: 0.441 \pm 0.121$ &  $\sigma: 0.306 \pm 0.119$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.462 \pm 0.022$ &      $\rho: 0.411 \pm 0.02$ &    $\rho: 0.442 \pm 0.019$ &    $\rho: 0.647 \pm 0.016$ &     $\rho: 0.46 \pm 0.019$ \\
#     &          & no-topic &  $\sigma: 0.413 \pm 0.016$ &   $\sigma: 0.402 \pm 0.014$ &  $\sigma: 0.436 \pm 0.018$ &  $\sigma: 0.625 \pm 0.015$ &   $\sigma: 0.45 \pm 0.026$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.482 \pm 0.015$ &      $\rho: 0.33 \pm 0.083$ &     $\rho: 0.39 \pm 0.044$ &    $\rho: 0.441 \pm 0.137$ &    $\rho: 0.735 \pm 0.047$ \\
#     &          & topic &  $\sigma: 0.429 \pm 0.012$ &   $\sigma: 0.352 \pm 0.057$ &  $\sigma: 0.378 \pm 0.122$ &   $\sigma: 0.44 \pm 0.138$ &  $\sigma: 0.746 \pm 0.048$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.502 \pm 0.005$ &     $\rho: 0.375 \pm 0.017$ &    $\rho: 0.468 \pm 0.021$ &    $\rho: 0.666 \pm 0.007$ &    $\rho: 0.635 \pm 0.065$ \\
#     &          & topic &  $\sigma: 0.449 \pm 0.006$ &    $\sigma: 0.278 \pm 0.03$ &  $\sigma: 0.531 \pm 0.086$ &   $\sigma: 0.64 \pm 0.008$ &   $\sigma: 0.69 \pm 0.062$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{All except UKPConvArgRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.439 \pm 0.022$ &     $\rho: 0.409 \pm 0.049$ &    $\rho: 0.285 \pm 0.058$ &    $\rho: 0.446 \pm 0.095$ &    $\rho: 0.378 \pm 0.083$ \\
#     &          & no-topic &   $\sigma: 0.378 \pm 0.02$ &   $\sigma: 0.392 \pm 0.044$ &  $\sigma: 0.317 \pm 0.061$ &  $\sigma: 0.432 \pm 0.109$ &  $\sigma: 0.335 \pm 0.101$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.412 \pm 0.011$ &      $\rho: 0.373 \pm 0.01$ &     $\rho: 0.58 \pm 0.023$ &    $\rho: 0.607 \pm 0.012$ &    $\rho: 0.481 \pm 0.026$ \\
#     &          & no-topic &  $\sigma: 0.344 \pm 0.012$ &   $\sigma: 0.346 \pm 0.014$ &  $\sigma: 0.543 \pm 0.027$ &  $\sigma: 0.572 \pm 0.011$ &  $\sigma: 0.497 \pm 0.028$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.475 \pm 0.009$ &     $\rho: 0.338 \pm 0.085$ &     $\rho: 0.41 \pm 0.056$ &    $\rho: 0.462 \pm 0.149$ &     $\rho: 0.758 \pm 0.05$ \\
#     &          & topic &  $\sigma: 0.425 \pm 0.015$ &   $\sigma: 0.318 \pm 0.081$ &  $\sigma: 0.583 \pm 0.067$ &   $\sigma: 0.462 \pm 0.15$ &  $\sigma: 0.772 \pm 0.043$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.513 \pm 0.006$ &     $\rho: 0.536 \pm 0.003$ &    $\rho: 0.531 \pm 0.027$ &    $\rho: 0.659 \pm 0.008$ &    $\rho: 0.613 \pm 0.014$ \\
#     &          & topic &  $\sigma: 0.458 \pm 0.008$ &   $\sigma: 0.506 \pm 0.006$ &  $\sigma: 0.692 \pm 0.015$ &   $\sigma: 0.632 \pm 0.01$ &  $\sigma: 0.676 \pm 0.015$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{All except Webis} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.442 \pm 0.023$ &     $\rho: 0.393 \pm 0.061$ &    $\rho: 0.293 \pm 0.087$ &     $\rho: 0.47 \pm 0.107$ &    $\rho: 0.677 \pm 0.054$ \\
#     &          & no-topic &   $\sigma: 0.38 \pm 0.014$ &   $\sigma: 0.384 \pm 0.057$ &  $\sigma: 0.425 \pm 0.081$ &  $\sigma: 0.462 \pm 0.116$ &  $\sigma: 0.628 \pm 0.066$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.418 \pm 0.009$ &     $\rho: 0.339 \pm 0.011$ &    $\rho: 0.467 \pm 0.015$ &    $\rho: 0.651 \pm 0.005$ &    $\rho: 0.643 \pm 0.027$ \\
#     &          & no-topic &   $\sigma: 0.35 \pm 0.009$ &   $\sigma: 0.316 \pm 0.017$ &  $\sigma: 0.421 \pm 0.025$ &   $\sigma: 0.63 \pm 0.007$ &  $\sigma: 0.722 \pm 0.028$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.469 \pm 0.016$ &       $\rho: 0.4 \pm 0.055$ &     $\rho: 0.257 \pm 0.09$ &    $\rho: 0.452 \pm 0.132$ &    $\rho: 0.619 \pm 0.077$ \\
#     &          & topic &  $\sigma: 0.413 \pm 0.013$ &     $\sigma: 0.39 \pm 0.05$ &   $\sigma: 0.33 \pm 0.072$ &  $\sigma: 0.446 \pm 0.139$ &  $\sigma: 0.547 \pm 0.099$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.414 \pm 0.007$ &      $\rho: 0.331 \pm 0.01$ &    $\rho: 0.484 \pm 0.007$ &     $\rho: 0.654 \pm 0.01$ &     $\rho: 0.53 \pm 0.024$ \\
#     &          & topic &  $\sigma: 0.347 \pm 0.006$ &    $\sigma: 0.31 \pm 0.012$ &  $\sigma: 0.456 \pm 0.017$ &  $\sigma: 0.631 \pm 0.009$ &  $\sigma: 0.549 \pm 0.014$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{IBMArgQ} & \multirow{2}{*}{cross-topic} & no-topic &     $\rho: 0.49 \pm 0.013$ &     $\rho: 0.434 \pm 0.052$ &    $\rho: 0.396 \pm 0.074$ &    $\rho: 0.392 \pm 0.111$ &    $\rho: 0.577 \pm 0.091$ \\
#     &          & no-topic &  $\sigma: 0.434 \pm 0.009$ &   $\sigma: 0.435 \pm 0.045$ &  $\sigma: 0.506 \pm 0.069$ &   $\sigma: 0.39 \pm 0.113$ &  $\sigma: 0.512 \pm 0.096$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.504 \pm 0.002$ &     $\rho: 0.439 \pm 0.004$ &    $\rho: 0.444 \pm 0.035$ &     $\rho: 0.466 \pm 0.01$ &    $\rho: 0.445 \pm 0.021$ \\
#     &          & no-topic &  $\sigma: 0.447 \pm 0.003$ &   $\sigma: 0.416 \pm 0.003$ &  $\sigma: 0.487 \pm 0.006$ &  $\sigma: 0.496 \pm 0.009$ &  $\sigma: 0.383 \pm 0.031$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.474 \pm 0.019$ &     $\rho: 0.424 \pm 0.051$ &     $\rho: 0.402 \pm 0.09$ &    $\rho: 0.337 \pm 0.119$ &    $\rho: 0.586 \pm 0.075$ \\
#     &          & topic &  $\sigma: 0.417 \pm 0.014$ &   $\sigma: 0.419 \pm 0.042$ &  $\sigma: 0.511 \pm 0.077$ &   $\sigma: 0.347 \pm 0.11$ &  $\sigma: 0.546 \pm 0.091$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.511 \pm 0.004$ &      $\rho: 0.456 \pm 0.01$ &    $\rho: 0.441 \pm 0.018$ &     $\rho: 0.381 \pm 0.02$ &    $\rho: 0.325 \pm 0.045$ \\
#     &          & topic &  $\sigma: 0.456 \pm 0.005$ &   $\sigma: 0.406 \pm 0.011$ &  $\sigma: 0.559 \pm 0.014$ &  $\sigma: 0.432 \pm 0.031$ &  $\sigma: 0.337 \pm 0.051$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{SwanRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.218 \pm 0.034$ &     $\rho: 0.241 \pm 0.034$ &       $\rho: 0.35 \pm 0.1$ &      $\rho: 0.462 \pm 0.1$ &    $\rho: 0.547 \pm 0.222$ \\
#     &          & no-topic &  $\sigma: 0.154 \pm 0.024$ &   $\sigma: 0.166 \pm 0.044$ &  $\sigma: 0.394 \pm 0.114$ &   $\sigma: 0.45 \pm 0.111$ &  $\sigma: 0.511 \pm 0.205$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.228 \pm 0.006$ &     $\rho: 0.295 \pm 0.012$ &     $\rho: 0.55 \pm 0.013$ &    $\rho: 0.647 \pm 0.007$ &    $\rho: 0.548 \pm 0.019$ \\
#     &          & no-topic &  $\sigma: 0.159 \pm 0.005$ &   $\sigma: 0.189 \pm 0.019$ &  $\sigma: 0.468 \pm 0.025$ &  $\sigma: 0.616 \pm 0.005$ &  $\sigma: 0.539 \pm 0.015$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &     $\rho: 0.11 \pm 0.048$ &      $\rho: 0.163 \pm 0.06$ &    $\rho: 0.307 \pm 0.092$ &    $\rho: 0.465 \pm 0.128$ &    $\rho: 0.443 \pm 0.195$ \\
#     &          & topic &  $\sigma: 0.067 \pm 0.043$ &   $\sigma: 0.101 \pm 0.071$ &  $\sigma: 0.277 \pm 0.137$ &   $\sigma: 0.45 \pm 0.138$ &  $\sigma: 0.365 \pm 0.169$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.108 \pm 0.048$ &     $\rho: 0.205 \pm 0.032$ &    $\rho: 0.418 \pm 0.037$ &    $\rho: 0.677 \pm 0.005$ &    $\rho: 0.381 \pm 0.039$ \\
#     &          & topic &   $\sigma: 0.082 \pm 0.04$ &   $\sigma: 0.069 \pm 0.036$ &   $\sigma: 0.458 \pm 0.05$ &  $\sigma: 0.651 \pm 0.008$ &   $\sigma: 0.36 \pm 0.055$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{IBMRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.373 \pm 0.032$ &     $\rho: 0.384 \pm 0.082$ &    $\rho: 0.287 \pm 0.104$ &    $\rho: 0.326 \pm 0.075$ &    $\rho: 0.276 \pm 0.202$ \\
#     &          & no-topic &  $\sigma: 0.348 \pm 0.028$ &   $\sigma: 0.366 \pm 0.072$ &   $\sigma: 0.355 \pm 0.14$ &  $\sigma: 0.329 \pm 0.076$ &  $\sigma: 0.328 \pm 0.204$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.415 \pm 0.004$ &     $\rho: 0.504 \pm 0.005$ &    $\rho: 0.293 \pm 0.035$ &    $\rho: 0.318 \pm 0.035$ &    $\rho: 0.249 \pm 0.053$ \\
#     &          & no-topic &  $\sigma: 0.389 \pm 0.003$ &   $\sigma: 0.477 \pm 0.004$ &   $\sigma: 0.39 \pm 0.016$ &   $\sigma: 0.338 \pm 0.04$ &  $\sigma: 0.268 \pm 0.052$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.324 \pm 0.043$ &     $\rho: 0.341 \pm 0.091$ &    $\rho: 0.338 \pm 0.104$ &    $\rho: 0.311 \pm 0.087$ &    $\rho: 0.349 \pm 0.225$ \\
#     &          & topic &  $\sigma: 0.303 \pm 0.038$ &   $\sigma: 0.324 \pm 0.086$ &  $\sigma: 0.406 \pm 0.168$ &   $\sigma: 0.31 \pm 0.084$ &  $\sigma: 0.389 \pm 0.232$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.394 \pm 0.006$ &     $\rho: 0.515 \pm 0.014$ &     $\rho: 0.335 \pm 0.03$ &     $\rho: 0.28 \pm 0.028$ &    $\rho: 0.213 \pm 0.071$ \\
#     &          & topic &  $\sigma: 0.377 \pm 0.005$ &   $\sigma: 0.486 \pm 0.017$ &  $\sigma: 0.484 \pm 0.071$ &  $\sigma: 0.315 \pm 0.037$ &   $\sigma: 0.226 \pm 0.09$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{UKPConvArgRank} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.058 \pm 0.057$ &    $\rho: -0.068 \pm 0.062$ &    $\rho: 0.267 \pm 0.148$ &     $\rho: 0.303 \pm 0.09$ &    $\rho: 0.543 \pm 0.066$ \\
#     &          & no-topic &  $\sigma: 0.036 \pm 0.052$ &  $\sigma: -0.097 \pm 0.058$ &  $\sigma: 0.315 \pm 0.206$ &  $\sigma: 0.305 \pm 0.087$ &  $\sigma: 0.445 \pm 0.079$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &    $\rho: 0.102 \pm 0.051$ &     $\rho: -0.04 \pm 0.086$ &    $\rho: 0.384 \pm 0.051$ &     $\rho: 0.45 \pm 0.028$ &    $\rho: 0.512 \pm 0.027$ \\
#     &          & no-topic &   $\sigma: 0.08 \pm 0.047$ &   $\sigma: -0.08 \pm 0.084$ &   $\sigma: 0.302 \pm 0.02$ &    $\sigma: 0.41 \pm 0.03$ &   $\sigma: 0.46 \pm 0.023$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.048 \pm 0.044$ &    $\rho: -0.045 \pm 0.122$ &    $\rho: 0.131 \pm 0.062$ &    $\rho: 0.316 \pm 0.112$ &    $\rho: 0.519 \pm 0.131$ \\
#     &          & topic &  $\sigma: 0.029 \pm 0.039$ &  $\sigma: -0.054 \pm 0.132$ &  $\sigma: 0.108 \pm 0.197$ &  $\sigma: 0.308 \pm 0.117$ &  $\sigma: 0.417 \pm 0.134$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.077 \pm 0.057$ &    $\rho: -0.081 \pm 0.065$ &    $\rho: 0.149 \pm 0.092$ &    $\rho: 0.419 \pm 0.053$ &    $\rho: 0.483 \pm 0.038$ \\
#     &          & topic &  $\sigma: 0.065 \pm 0.052$ &  $\sigma: -0.063 \pm 0.075$ &  $\sigma: 0.009 \pm 0.112$ &  $\sigma: 0.367 \pm 0.055$ &  $\sigma: 0.477 \pm 0.073$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{8}{*}{Webis} & \multirow{2}{*}{cross-topic} & no-topic &    $\rho: 0.214 \pm 0.034$ &     $\rho: 0.213 \pm 0.063$ &    $\rho: 0.264 \pm 0.063$ &    $\rho: 0.251 \pm 0.105$ &     $\rho: 0.494 \pm 0.08$ \\
#     &          & no-topic &  $\sigma: 0.214 \pm 0.031$ &   $\sigma: 0.225 \pm 0.064$ &  $\sigma: 0.324 \pm 0.114$ &  $\sigma: 0.242 \pm 0.108$ &  $\sigma: 0.528 \pm 0.097$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & no-topic &     $\rho: 0.257 \pm 0.01$ &      $\rho: 0.24 \pm 0.032$ &    $\rho: 0.394 \pm 0.029$ &    $\rho: 0.329 \pm 0.043$ &    $\rho: 0.396 \pm 0.025$ \\
#     &          & no-topic &  $\sigma: 0.258 \pm 0.006$ &    $\sigma: 0.22 \pm 0.031$ &  $\sigma: 0.513 \pm 0.049$ &  $\sigma: 0.373 \pm 0.047$ &  $\sigma: 0.465 \pm 0.037$ \\
# \cline{2-8}
#     & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.214 \pm 0.034$ &     $\rho: 0.213 \pm 0.063$ &    $\rho: 0.264 \pm 0.063$ &    $\rho: 0.251 \pm 0.105$ &     $\rho: 0.494 \pm 0.08$ \\
#     &          & topic &  $\sigma: 0.214 \pm 0.031$ &   $\sigma: 0.225 \pm 0.064$ &  $\sigma: 0.324 \pm 0.114$ &  $\sigma: 0.242 \pm 0.108$ &  $\sigma: 0.528 \pm 0.097$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &     $\rho: 0.257 \pm 0.01$ &     $\rho: 0.239 \pm 0.032$ &    $\rho: 0.394 \pm 0.029$ &    $\rho: 0.329 \pm 0.043$ &    $\rho: 0.396 \pm 0.025$ \\
#     &          & topic &  $\sigma: 0.258 \pm 0.006$ &    $\sigma: 0.22 \pm 0.031$ &  $\sigma: 0.512 \pm 0.048$ &  $\sigma: 0.373 \pm 0.047$ &  $\sigma: 0.464 \pm 0.036$ \\
# \cline{1-8}
# \cline{2-8}
# \multirow{4}{*}{All} & \multirow{2}{*}{cross-topic} & topic &    $\rho: 0.477 \pm 0.012$ &      $\rho: 0.41 \pm 0.075$ &    $\rho: 0.273 \pm 0.062$ &    $\rho: 0.436 \pm 0.112$ &    $\rho: 0.727 \pm 0.053$ \\
#     &          & topic &    $\sigma: 0.42 \pm 0.01$ &   $\sigma: 0.394 \pm 0.067$ &  $\sigma: 0.338 \pm 0.149$ &  $\sigma: 0.432 \pm 0.114$ &  $\sigma: 0.748 \pm 0.051$ \\
# \cline{2-8}
#     & \multirow{2}{*}{in-topic} & topic &    $\rho: 0.496 \pm 0.006$ &     $\rho: 0.522 \pm 0.018$ &    $\rho: 0.329 \pm 0.032$ &     $\rho: 0.67 \pm 0.008$ &     $\rho: 0.601 \pm 0.02$ \\
#     &          & topic &   $\sigma: 0.44 \pm 0.009$ &   $\sigma: 0.497 \pm 0.019$ &  $\sigma: 0.318 \pm 0.083$ &  $\sigma: 0.645 \pm 0.012$ &  $\sigma: 0.674 \pm 0.016$ \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Multi Task Learning

# %%
eval_results = pd.read_csv("evaluation_results.csv", sep=",")
multi_task_results = eval_results[eval_results["task_id"].isin(["MTLAS", "MTLAS_topic"])].reset_index(drop=True)
mtlas_loo_gretz = pd.read_csv("eval_mtlas_loo_gretz.csv", sep=";")
mtlas_loo_toledo = pd.read_csv("eval_mtlas_loo_toledo.csv", sep=";")
mtlas_loo_swanson = pd.read_csv("eval_mtlas_loo_swanson.csv", sep=";")
mtlas_loo_ukp = pd.read_csv("eval_mtlas_loo_ukp.csv", sep=";")
mtlas_loo_webis = pd.read_csv("eval_mtlas_loo_webis.csv", sep=";")
infer_results = pd.read_csv("infer_results1.csv", sep=";")

multi_task_data = [multi_task_results, mtlas_loo_gretz, mtlas_loo_toledo, mtlas_loo_swanson, mtlas_loo_ukp, mtlas_loo_webis]

# %%
infer_results
# Out:
#     ukp_pearson  ukp_spearman  toledo_pearson  toledo_spearman  webis_pearson  \
# 0         0.655         0.485           0.250            0.167          0.456
# 1         0.606         0.468           0.249            0.128          0.501
# 2         0.596         0.601           0.497            0.451          0.718
# 3         0.595         0.527           0.415            0.311          0.708
# 4         0.587         0.442           0.258            0.185          0.394
# ..          ...           ...             ...              ...            ...
# 67        0.216         0.332           0.512            0.484          0.228
# 68        0.198         0.467           0.233            0.173          0.179
# 69        0.111         0.326           0.157            0.110          0.373
# 70        0.096         0.302           0.196            0.244          0.126
# 71        0.036         0.357           0.086           -0.081          0.377
#
#     webis_spearman  swanson_pearson  swanson_spearman  gretz_pearson  \
# 0            0.629            0.436             0.450          0.229
# 1            0.602            0.457             0.480          0.331
# 2            0.745            0.625             0.621          0.493
# 3            0.716            0.584             0.602          0.469
# 4            0.576            0.393             0.446          0.320
# ..             ...              ...               ...            ...
# 67           0.215            0.599             0.613          0.446
# 68           0.274            0.360             0.439          0.216
# 69           0.448            0.286             0.298          0.242
# 70           0.267            0.364             0.423          0.216
# 71           0.339            0.344             0.407          0.061
#
#     gretz_spearman                task_name     sampling aggregation_method
# 0            0.224    MTLAS_LOO_gretz_topic     in-topic                var
# 1            0.298              MTLAS_topic     in-topic                var
# 2            0.445              MTLAS_topic     in-topic               mean
# 3            0.410              MTLAS_topic     in-topic             wt-var
# 4            0.315        MTLAS_LOO_swanson     in-topic                var
# ..             ...                      ...          ...                ...
# 67           0.398    MTLAS_LOO_webis_topic  cross-topic               mean
# 68           0.208          MTLAS_LOO_webis  cross-topic                var
# 69           0.198  MTLAS_LOO_swanson_topic  cross-topic                var
# 70           0.215    MTLAS_LOO_webis_topic  cross-topic                var
# 71           0.021    MTLAS_LOO_gretz_topic  cross-topic                var
#
# [72 rows x 13 columns]

# %%
complete_set = pd.DataFrame(columns=["task_id", "sampling", "use_topic", "aggregation", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"])
for result_set in multi_task_data:
    
    result_set["use_topic"] = result_set["task_id"].str.contains("_topic")
    d = {True: 'topic', False: 'no-topic'}
    results = result_set.replace(d)
    datasets = ['gretz', 'swanson', 'ukp', 'webis', 'toledo']
    aggregated_cols = [col for col in results.columns if any(s in col for s in datasets)]
    results_by_task = results.groupby(["task_id", "sampling", "use_topic"], as_index=False).agg(
        {
            d: ['mean', 'std']
            for d in aggregated_cols
        }).round(3)
    
    # extract the values into a new dataframe.
    task_details = results_by_task.loc[:, (slice(None), '')]
    task_details.columns = task_details.columns.get_level_values(0)
    means = results_by_task.loc[:, (slice(None), 'mean')]
    means.columns = means.columns.get_level_values(0)
    stds = results_by_task.loc[:, (slice(None), 'std')]
    stds.columns = stds.columns.get_level_values(0)
    
    #  separate pearson and spearman
    pearson_means = means.filter(regex='pearson')
    pearson_stds = stds.filter(regex='pearson')
    pearson_stds.columns = "d_" + pearson_stds.columns
    pearson_data = pd.concat([task_details, pearson_means, pearson_stds], axis=1)
    spearman_means = means.filter(regex='spearman')
    spearman_stds = stds.filter(regex='spearman')
    spearman_stds.columns = "d_" + spearman_stds.columns
    spearman_data = pd.concat([task_details, spearman_means, spearman_stds], axis=1)
    
    #  combine the mean and std values for the pearson coeffients.

    if "gretz_pearson" in pearson_data.columns:
        pearson_data["IBMArgQ"] = [
            "$\rho: " + str(pearson_data["gretz_pearson"][i]) + " \pm " + str(pearson_data["d_gretz_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["IBMArgQ"] = [
            "$\sigma: " + str(spearman_data["gretz_spearman"][i]) + " \pm " + str(spearman_data["d_gretz_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["IBMArgQ"] = None
        spearman_data["IBMArgQ"] = None
        
    if "toledo_pearson" in pearson_data.columns:
        pearson_data["IBMRank"] = [
            "$\rho: " + str(pearson_data["toledo_pearson"][i]) + " \pm " + str(pearson_data["d_toledo_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["IBMRank"] = [
            "$\sigma: " + str(spearman_data["toledo_spearman"][i]) + " \pm " + str(spearman_data["d_toledo_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["IBMRank"] = None
        spearman_data["IBMRank"] = None
    
    if "ukp_pearson" in pearson_data.columns:
        pearson_data["UKPConvArgRank"] = [
            "$\rho: " + str(pearson_data["ukp_pearson"][i]) + " \pm " + str(pearson_data["d_ukp_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["UKPConvArgRank"] = [
            "$\sigma: " + str(spearman_data["ukp_spearman"][i]) + " \pm " + str(spearman_data["d_ukp_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["UKPConvArgRank"] = None
        spearman_data["UKPConvArgRank"] = None
    
    if "swanson_pearson" in pearson_data.columns:
        pearson_data["SwanRank"] = [
            "$\rho: " + str(pearson_data["swanson_pearson"][i]) + " \pm " + str(pearson_data["d_swanson_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["SwanRank"] = [
            "$\sigma: " + str(spearman_data["swanson_spearman"][i]) + " \pm " + str(spearman_data["d_swanson_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["SwanRank"] = None
        spearman_data["SwanRank"] = None
    
    if "webis_pearson" in pearson_data.columns:
        pearson_data["Webis"] = [
            "$\rho: " + str(pearson_data["webis_pearson"][i]) + " \pm " + str(pearson_data["d_webis_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["Webis"] = [
            "$\sigma: " + str(spearman_data["webis_spearman"][i]) + " \pm " + str(spearman_data["d_webis_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
    else:
        pearson_data["Webis"] = None
        spearman_data["Webis"] = None
    
    final_pearson = pearson_data[
        ["task_id", "sampling", "use_topic", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]
    final_spearman = spearman_data[
        ["task_id", "sampling", "use_topic", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]
    
    metrics_table = pd.concat([final_pearson, final_spearman]).sort_values(by=["task_id", "sampling", "use_topic"])
    metrics_table["aggregation"] = "None"
    complete_set = pd.concat([complete_set, metrics_table]).reset_index(drop=True)

# %%
complete_set.head()
# Out:
#        task_id     sampling use_topic aggregation                    IBMArgQ  \
# 0        MTLAS  cross-topic  no-topic        None    $\rho: 0.495 \pm 0.015$
# 1        MTLAS  cross-topic  no-topic        None  $\sigma: 0.439 \pm 0.014$
# 2        MTLAS     in-topic  no-topic        None    $\rho: 0.511 \pm 0.004$
# 3        MTLAS     in-topic  no-topic        None  $\sigma: 0.457 \pm 0.004$
# 4  MTLAS_topic  cross-topic     topic        None    $\rho: 0.482 \pm 0.014$
#
#                      IBMRank             UKPConvArgRank  \
# 0     $\rho: 0.44 \pm 0.064$     $\rho: 0.416 \pm 0.11$
# 1  $\sigma: 0.421 \pm 0.058$  $\sigma: 0.499 \pm 0.145$
# 2     $\rho: 0.52 \pm 0.012$      $\rho: 0.6 \pm 0.034$
# 3  $\sigma: 0.501 \pm 0.014$  $\sigma: 0.565 \pm 0.043$
# 4    $\rho: 0.429 \pm 0.072$    $\rho: 0.434 \pm 0.096$
#
#                     SwanRank                      Webis
# 0    $\rho: 0.505 \pm 0.132$     $\rho: 0.79 \pm 0.047$
# 1  $\sigma: 0.492 \pm 0.145$  $\sigma: 0.794 \pm 0.051$
# 2     $\rho: 0.66 \pm 0.006$    $\rho: 0.559 \pm 0.021$
# 3  $\sigma: 0.633 \pm 0.006$  $\sigma: 0.593 \pm 0.029$
# 4    $\rho: 0.494 \pm 0.141$    $\rho: 0.786 \pm 0.049$

# %%
infer_results.rename(columns={"task_name": "task_id", "aggregation_method": "aggregation"}, inplace=True)

# define topic information
infer_results["use_topic"] = infer_results["task_id"].str.contains("_topic")
d = {True: 'topic', False: 'no-topic'}
results = infer_results.replace(d)
pearson_data = results[["task_id","sampling","use_topic",
                              "aggregation","gretz_pearson","toledo_pearson",
                              "ukp_pearson","swanson_pearson","webis_pearson"]]
spearman_data = results[["task_id","sampling","use_topic",
                              "aggregation","gretz_spearman","toledo_spearman",
                              "ukp_spearman","swanson_spearman","webis_spearman"]]

# separate out pearson and spearman and rewrite
if "gretz_pearson" in pearson_data.columns:
        pearson_data["IBMArgQ"] = [
            "$\rho: " + str(pearson_data["gretz_pearson"][i]) + "$"
            for i in range(len(pearson_data))]
        spearman_data["IBMArgQ"] = [
            "$\sigma: " + str(spearman_data["gretz_spearman"][i]) + "$"
            for i in range(len(spearman_data))]
else:
    pearson_data["IBMArgQ"] = None
    spearman_data["IBMArgQ"] = None
    
if "toledo_pearson" in pearson_data.columns:
    pearson_data["IBMRank"] = [
        "$\rho: " + str(pearson_data["toledo_pearson"][i])  + "$"
        for i in range(len(pearson_data))]
    spearman_data["IBMRank"] = [
        "$\sigma: " + str(spearman_data["toledo_spearman"][i])  + "$"
        for i in range(len(spearman_data))]
else:
    pearson_data["IBMRank"] = None
    spearman_data["IBMRank"] = None

if "ukp_pearson" in pearson_data.columns:
    pearson_data["UKPConvArgRank"] = [
        "$\rho: " + str(pearson_data["ukp_pearson"][i]) + "$"
        for i in range(len(pearson_data))]
    spearman_data["UKPConvArgRank"] = [
        "$\sigma: " + str(spearman_data["ukp_spearman"][i])  + "$"
        for i in range(len(spearman_data))]
else:
    pearson_data["UKPConvArgRank"] = None
    spearman_data["UKPConvArgRank"] = None

if "swanson_pearson" in pearson_data.columns:
    pearson_data["SwanRank"] = [
        "$\rho: " + str(pearson_data["swanson_pearson"][i]) + "$"
        for i in range(len(pearson_data))]
    spearman_data["SwanRank"] = [
        "$\sigma: " + str(spearman_data["swanson_spearman"][i]) + "$"
        for i in range(len(spearman_data))]
else:
    pearson_data["SwanRank"] = None
    spearman_data["SwanRank"] = None

if "webis_pearson" in pearson_data.columns:
    pearson_data["Webis"] = [
        "$\rho: " + str(pearson_data["webis_pearson"][i]) + "$"
        for i in range(len(pearson_data))]
    spearman_data["Webis"] = [
        "$\sigma: " + str(spearman_data["webis_spearman"][i]) + "$"
        for i in range(len(spearman_data))]
else:
    pearson_data["Webis"] = None
    spearman_data["Webis"] = None

final_pearson = pearson_data[
    ["task_id", "sampling", "use_topic", "aggregation", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]
final_spearman = spearman_data[
    ["task_id", "sampling", "use_topic", "aggregation", "IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]]

infer_table = pd.concat([final_pearson, final_spearman]).sort_values(by=["task_id", "sampling", "use_topic", "aggregation"]).reset_index(drop=True)
# Out:
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Siddharth\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
complete_set.head()
# Out:
#        task_id     sampling use_topic aggregation                    IBMArgQ  \
# 0        MTLAS  cross-topic  no-topic        None    $\rho: 0.495 \pm 0.015$
# 1        MTLAS  cross-topic  no-topic        None  $\sigma: 0.439 \pm 0.014$
# 2        MTLAS     in-topic  no-topic        None    $\rho: 0.511 \pm 0.004$
# 3        MTLAS     in-topic  no-topic        None  $\sigma: 0.457 \pm 0.004$
# 4  MTLAS_topic  cross-topic     topic        None    $\rho: 0.482 \pm 0.014$
#
#                      IBMRank             UKPConvArgRank  \
# 0     $\rho: 0.44 \pm 0.064$     $\rho: 0.416 \pm 0.11$
# 1  $\sigma: 0.421 \pm 0.058$  $\sigma: 0.499 \pm 0.145$
# 2     $\rho: 0.52 \pm 0.012$      $\rho: 0.6 \pm 0.034$
# 3  $\sigma: 0.501 \pm 0.014$  $\sigma: 0.565 \pm 0.043$
# 4    $\rho: 0.429 \pm 0.072$    $\rho: 0.434 \pm 0.096$
#
#                     SwanRank                      Webis
# 0    $\rho: 0.505 \pm 0.132$     $\rho: 0.79 \pm 0.047$
# 1  $\sigma: 0.492 \pm 0.145$  $\sigma: 0.794 \pm 0.051$
# 2     $\rho: 0.66 \pm 0.006$    $\rho: 0.559 \pm 0.021$
# 3  $\sigma: 0.633 \pm 0.006$  $\sigma: 0.593 \pm 0.029$
# 4    $\rho: 0.494 \pm 0.141$    $\rho: 0.786 \pm 0.049$

# %%
infer_table.head()
# Out:
#   task_id     sampling use_topic aggregation           IBMArgQ  \
# 0   MTLAS  cross-topic  no-topic        mean    $\rho: 0.4717$
# 1   MTLAS  cross-topic  no-topic        mean  $\sigma: 0.4101$
# 2   MTLAS  cross-topic  no-topic         var    $\rho: 0.2748$
# 3   MTLAS  cross-topic  no-topic         var  $\sigma: 0.1804$
# 4   MTLAS  cross-topic  no-topic      wt-var     $\rho: 0.449$
#
#             IBMRank    UKPConvArgRank          SwanRank             Webis
# 0    $\rho: 0.3574$     $\rho: 0.402$    $\rho: 0.6171$    $\rho: 0.7976$
# 1  $\sigma: 0.3375$    $\sigma: 0.69$   $\sigma: 0.624$  $\sigma: 0.7921$
# 2    $\rho: 0.1683$    $\rho: 0.2586$    $\rho: 0.3982$    $\rho: 0.5949$
# 3  $\sigma: 0.0559$  $\sigma: 0.5811$  $\sigma: 0.4466$  $\sigma: 0.5045$
# 4    $\rho: 0.3422$    $\rho: 0.3987$    $\rho: 0.5932$     $\rho: 0.779$

# %%
mtl_table = pd.concat([complete_set, infer_table]).sort_values(by=["task_id", "sampling", "use_topic", "aggregation"]).reset_index(drop=True)

# %%
#  rename task names
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS_LOO_gretz")==True] = "All except IBMArgQ"
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS_LOO_toledo")==True] = "All except IBMRank"
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS_LOO_ukp")==True] = "All except UKPConvArgRank"
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS_LOO_swanson")==True] = "All except SwanRank"
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS_LOO_webis")==True] = "All except Webis"
mtl_table["task_id"][mtl_table["task_id"].str.contains("MTLAS")==True] = "All"

mtl_table.sort_values(by=["task_id", "sampling", "use_topic", "aggregation"], inplace=True)

# %%
#  Define the latex table structure.
col1 = mtl_table["task_id"].tolist()
col2 = mtl_table["sampling"].tolist()
col3 = mtl_table["use_topic"].tolist()
col4 = mtl_table["aggregation"].tolist()
cidx = ["IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"]
iidx = pd.MultiIndex.from_arrays([
    col1, col2, col3, col4
    ])

# %%
mtl_metrics_table = mtl_table.iloc[:, 4:]
values_list = mtl_metrics_table.values.tolist()
mtl_latex_table = pd.DataFrame(
    values_list, columns=cidx, index=iidx)

# %%
mtl_latex_table.head(30)
# Out:
#                                                    IBMArgQ  \
# All cross-topic no-topic None      $\rho: 0.495 \pm 0.015$
#                          None    $\sigma: 0.439 \pm 0.014$
#                          mean               $\rho: 0.4717$
#                          mean             $\sigma: 0.4101$
#                          var                $\rho: 0.2748$
#                          var              $\sigma: 0.1804$
#                          wt-var           $\sigma: 0.3861$
#                          wt-var              $\rho: 0.449$
#                 topic    None     $\sigma: 0.422 \pm 0.01$
#                          None      $\rho: 0.482 \pm 0.014$
#                          mean             $\sigma: 0.3965$
#                          mean               $\rho: 0.4508$
#                          var               $\sigma: 0.181$
#                          var                $\rho: 0.2615$
#                          wt-var           $\sigma: 0.3792$
#                          wt-var             $\rho: 0.4328$
#     in-topic    no-topic None      $\rho: 0.511 \pm 0.004$
#                          None    $\sigma: 0.457 \pm 0.004$
#                          mean             $\sigma: 0.4269$
#                          mean               $\rho: 0.4754$
#                          var                $\rho: 0.3105$
#                          var              $\sigma: 0.3278$
#                          wt-var             $\rho: 0.4469$
#                          wt-var           $\sigma: 0.3997$
#                 topic    None    $\sigma: 0.463 \pm 0.004$
#                          None      $\rho: 0.515 \pm 0.004$
#                          mean             $\sigma: 0.4445$
#                          mean                $\rho: 0.493$
#                          var               $\sigma: 0.298$
#                          var                $\rho: 0.3313$
#
#                                                    IBMRank  \
# All cross-topic no-topic None       $\rho: 0.44 \pm 0.064$
#                          None    $\sigma: 0.421 \pm 0.058$
#                          mean               $\rho: 0.3574$
#                          mean             $\sigma: 0.3375$
#                          var                $\rho: 0.1683$
#                          var              $\sigma: 0.0559$
#                          wt-var           $\sigma: 0.3225$
#                          wt-var             $\rho: 0.3422$
#                 topic    None    $\sigma: 0.407 \pm 0.069$
#                          None      $\rho: 0.429 \pm 0.072$
#                          mean             $\sigma: 0.3275$
#                          mean               $\rho: 0.3499$
#                          var             $\sigma: -0.0142$
#                          var                $\rho: 0.1056$
#                          wt-var           $\sigma: 0.2785$
#                          wt-var             $\rho: 0.3151$
#     in-topic    no-topic None       $\rho: 0.52 \pm 0.012$
#                          None    $\sigma: 0.501 \pm 0.014$
#                          mean             $\sigma: 0.4397$
#                          mean               $\rho: 0.4576$
#                          var                $\rho: 0.2157$
#                          var              $\sigma: 0.2001$
#                          wt-var              $\rho: 0.457$
#                          wt-var           $\sigma: 0.4414$
#                 topic    None    $\sigma: 0.508 \pm 0.009$
#                          None      $\rho: 0.535 \pm 0.007$
#                          mean             $\sigma: 0.4506$
#                          mean               $\rho: 0.4971$
#                          var              $\sigma: 0.1278$
#                          var                $\rho: 0.2494$
#
#                                             UKPConvArgRank  \
# All cross-topic no-topic None       $\rho: 0.416 \pm 0.11$
#                          None    $\sigma: 0.499 \pm 0.145$
#                          mean                $\rho: 0.402$
#                          mean               $\sigma: 0.69$
#                          var                $\rho: 0.2586$
#                          var              $\sigma: 0.5811$
#                          wt-var           $\sigma: 0.6965$
#                          wt-var             $\rho: 0.3987$
#                 topic    None    $\sigma: 0.502 \pm 0.165$
#                          None      $\rho: 0.434 \pm 0.096$
#                          mean              $\sigma: 0.594$
#                          mean               $\rho: 0.4179$
#                          var              $\sigma: 0.5511$
#                          var                $\rho: 0.2364$
#                          wt-var           $\sigma: 0.6453$
#                          wt-var             $\rho: 0.4311$
#     in-topic    no-topic None        $\rho: 0.6 \pm 0.034$
#                          None    $\sigma: 0.565 \pm 0.043$
#                          mean             $\sigma: 0.5024$
#                          mean               $\rho: 0.5168$
#                          var                $\rho: 0.5423$
#                          var              $\sigma: 0.4719$
#                          wt-var             $\rho: 0.4922$
#                          wt-var           $\sigma: 0.4626$
#                 topic    None    $\sigma: 0.646 \pm 0.035$
#                          None      $\rho: 0.654 \pm 0.042$
#                          mean             $\sigma: 0.6011$
#                          mean               $\rho: 0.5958$
#                          var              $\sigma: 0.4681$
#                          var                $\rho: 0.6061$
#
#                                                   SwanRank  \
# All cross-topic no-topic None      $\rho: 0.505 \pm 0.132$
#                          None    $\sigma: 0.492 \pm 0.145$
#                          mean               $\rho: 0.6171$
#                          mean              $\sigma: 0.624$
#                          var                $\rho: 0.3982$
#                          var              $\sigma: 0.4466$
#                          wt-var           $\sigma: 0.5988$
#                          wt-var             $\rho: 0.5932$
#                 topic    None    $\sigma: 0.484 \pm 0.153$
#                          None      $\rho: 0.494 \pm 0.141$
#                          mean             $\sigma: 0.5956$
#                          mean                $\rho: 0.588$
#                          var              $\sigma: 0.3083$
#                          var                $\rho: 0.3032$
#                          wt-var           $\sigma: 0.5568$
#                          wt-var             $\rho: 0.5531$
#     in-topic    no-topic None       $\rho: 0.66 \pm 0.006$
#                          None    $\sigma: 0.633 \pm 0.006$
#                          mean             $\sigma: 0.6021$
#                          mean               $\rho: 0.6029$
#                          var                 $\rho: 0.463$
#                          var              $\sigma: 0.5196$
#                          wt-var             $\rho: 0.5912$
#                          wt-var           $\sigma: 0.5918$
#                 topic    None    $\sigma: 0.653 \pm 0.005$
#                          None      $\rho: 0.679 \pm 0.005$
#                          mean             $\sigma: 0.6205$
#                          mean               $\rho: 0.6248$
#                          var              $\sigma: 0.4799$
#                          var                $\rho: 0.4567$
#
#                                                      Webis
# All cross-topic no-topic None       $\rho: 0.79 \pm 0.047$
#                          None    $\sigma: 0.794 \pm 0.051$
#                          mean               $\rho: 0.7976$
#                          mean             $\sigma: 0.7921$
#                          var                $\rho: 0.5949$
#                          var              $\sigma: 0.5045$
#                          wt-var            $\sigma: 0.753$
#                          wt-var              $\rho: 0.779$
#                 topic    None    $\sigma: 0.791 \pm 0.044$
#                          None      $\rho: 0.786 \pm 0.049$
#                          mean             $\sigma: 0.8015$
#                          mean               $\rho: 0.7995$
#                          var              $\sigma: 0.5853$
#                          var                $\rho: 0.5825$
#                          wt-var           $\sigma: 0.7551$
#                          wt-var             $\rho: 0.7749$
#     in-topic    no-topic None      $\rho: 0.559 \pm 0.021$
#                          None    $\sigma: 0.593 \pm 0.029$
#                          mean             $\sigma: 0.6979$
#                          mean                $\rho: 0.673$
#                          var                $\rho: 0.4422$
#                          var               $\sigma: 0.462$
#                          wt-var             $\rho: 0.6626$
#                          wt-var           $\sigma: 0.6446$
#                 topic    None     $\sigma: 0.65 \pm 0.013$
#                          None      $\rho: 0.598 \pm 0.016$
#                          mean             $\sigma: 0.7447$
#                          mean               $\rho: 0.7175$
#                          var              $\sigma: 0.6018$
#                          var                $\rho: 0.5011$

# %%
pd.options.display.float_format = '{:,.3f}'.format
ltx_code = mtl_latex_table.to_latex(
    caption="Multi Task Learning",
    longtable=False,
    header=["IBMArgQ", "IBMRank", "UKPConvArgRank", "SwanRank", "Webis"],
    position="H",
    escape=False,
    multirow=True,
    float_format="%.3f",
    column_format="|l|l|l|l|lllll|",
)

# %%
print(ltx_code)
# Out:
# \begin{table}[H]
# \centering
# \caption{Multi Task Learning}
# \begin{tabular}{|l|l|l|l|lllll|}
# \toprule
#                  &          &       &        &                    IBMArgQ &                    IBMRank &             UKPConvArgRank &                   SwanRank &                      Webis \\
# \midrule
# \multirow{32}{*}{All} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.495 \pm 0.015$ &     $\rho: 0.44 \pm 0.064$ &     $\rho: 0.416 \pm 0.11$ &    $\rho: 0.505 \pm 0.132$ &     $\rho: 0.79 \pm 0.047$ \\
#                  &          &       & None &  $\sigma: 0.439 \pm 0.014$ &  $\sigma: 0.421 \pm 0.058$ &  $\sigma: 0.499 \pm 0.145$ &  $\sigma: 0.492 \pm 0.145$ &  $\sigma: 0.794 \pm 0.051$ \\
#                  &          &       & mean &             $\rho: 0.4717$ &             $\rho: 0.3574$ &              $\rho: 0.402$ &             $\rho: 0.6171$ &             $\rho: 0.7976$ \\
#                  &          &       & mean &           $\sigma: 0.4101$ &           $\sigma: 0.3375$ &             $\sigma: 0.69$ &            $\sigma: 0.624$ &           $\sigma: 0.7921$ \\
#                  &          &       & var &             $\rho: 0.2748$ &             $\rho: 0.1683$ &             $\rho: 0.2586$ &             $\rho: 0.3982$ &             $\rho: 0.5949$ \\
#                  &          &       & var &           $\sigma: 0.1804$ &           $\sigma: 0.0559$ &           $\sigma: 0.5811$ &           $\sigma: 0.4466$ &           $\sigma: 0.5045$ \\
#                  &          &       & wt-var &           $\sigma: 0.3861$ &           $\sigma: 0.3225$ &           $\sigma: 0.6965$ &           $\sigma: 0.5988$ &            $\sigma: 0.753$ \\
#                  &          &       & wt-var &              $\rho: 0.449$ &             $\rho: 0.3422$ &             $\rho: 0.3987$ &             $\rho: 0.5932$ &              $\rho: 0.779$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &   $\sigma: 0.422 \pm 0.01$ &  $\sigma: 0.407 \pm 0.069$ &  $\sigma: 0.502 \pm 0.165$ &  $\sigma: 0.484 \pm 0.153$ &  $\sigma: 0.791 \pm 0.044$ \\
#                  &          &       & None &    $\rho: 0.482 \pm 0.014$ &    $\rho: 0.429 \pm 0.072$ &    $\rho: 0.434 \pm 0.096$ &    $\rho: 0.494 \pm 0.141$ &    $\rho: 0.786 \pm 0.049$ \\
#                  &          &       & mean &           $\sigma: 0.3965$ &           $\sigma: 0.3275$ &            $\sigma: 0.594$ &           $\sigma: 0.5956$ &           $\sigma: 0.8015$ \\
#                  &          &       & mean &             $\rho: 0.4508$ &             $\rho: 0.3499$ &             $\rho: 0.4179$ &              $\rho: 0.588$ &             $\rho: 0.7995$ \\
#                  &          &       & var &            $\sigma: 0.181$ &          $\sigma: -0.0142$ &           $\sigma: 0.5511$ &           $\sigma: 0.3083$ &           $\sigma: 0.5853$ \\
#                  &          &       & var &             $\rho: 0.2615$ &             $\rho: 0.1056$ &             $\rho: 0.2364$ &             $\rho: 0.3032$ &             $\rho: 0.5825$ \\
#                  &          &       & wt-var &           $\sigma: 0.3792$ &           $\sigma: 0.2785$ &           $\sigma: 0.6453$ &           $\sigma: 0.5568$ &           $\sigma: 0.7551$ \\
#                  &          &       & wt-var &             $\rho: 0.4328$ &             $\rho: 0.3151$ &             $\rho: 0.4311$ &             $\rho: 0.5531$ &             $\rho: 0.7749$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.511 \pm 0.004$ &     $\rho: 0.52 \pm 0.012$ &      $\rho: 0.6 \pm 0.034$ &     $\rho: 0.66 \pm 0.006$ &    $\rho: 0.559 \pm 0.021$ \\
#                  &          &       & None &  $\sigma: 0.457 \pm 0.004$ &  $\sigma: 0.501 \pm 0.014$ &  $\sigma: 0.565 \pm 0.043$ &  $\sigma: 0.633 \pm 0.006$ &  $\sigma: 0.593 \pm 0.029$ \\
#                  &          &       & mean &           $\sigma: 0.4269$ &           $\sigma: 0.4397$ &           $\sigma: 0.5024$ &           $\sigma: 0.6021$ &           $\sigma: 0.6979$ \\
#                  &          &       & mean &             $\rho: 0.4754$ &             $\rho: 0.4576$ &             $\rho: 0.5168$ &             $\rho: 0.6029$ &              $\rho: 0.673$ \\
#                  &          &       & var &             $\rho: 0.3105$ &             $\rho: 0.2157$ &             $\rho: 0.5423$ &              $\rho: 0.463$ &             $\rho: 0.4422$ \\
#                  &          &       & var &           $\sigma: 0.3278$ &           $\sigma: 0.2001$ &           $\sigma: 0.4719$ &           $\sigma: 0.5196$ &            $\sigma: 0.462$ \\
#                  &          &       & wt-var &             $\rho: 0.4469$ &              $\rho: 0.457$ &             $\rho: 0.4922$ &             $\rho: 0.5912$ &             $\rho: 0.6626$ \\
#                  &          &       & wt-var &           $\sigma: 0.3997$ &           $\sigma: 0.4414$ &           $\sigma: 0.4626$ &           $\sigma: 0.5918$ &           $\sigma: 0.6446$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &  $\sigma: 0.463 \pm 0.004$ &  $\sigma: 0.508 \pm 0.009$ &  $\sigma: 0.646 \pm 0.035$ &  $\sigma: 0.653 \pm 0.005$ &   $\sigma: 0.65 \pm 0.013$ \\
#                  &          &       & None &    $\rho: 0.515 \pm 0.004$ &    $\rho: 0.535 \pm 0.007$ &    $\rho: 0.654 \pm 0.042$ &    $\rho: 0.679 \pm 0.005$ &    $\rho: 0.598 \pm 0.016$ \\
#                  &          &       & mean &           $\sigma: 0.4445$ &           $\sigma: 0.4506$ &           $\sigma: 0.6011$ &           $\sigma: 0.6205$ &           $\sigma: 0.7447$ \\
#                  &          &       & mean &              $\rho: 0.493$ &             $\rho: 0.4971$ &             $\rho: 0.5958$ &             $\rho: 0.6248$ &             $\rho: 0.7175$ \\
#                  &          &       & var &            $\sigma: 0.298$ &           $\sigma: 0.1278$ &           $\sigma: 0.4681$ &           $\sigma: 0.4799$ &           $\sigma: 0.6018$ \\
#                  &          &       & var &             $\rho: 0.3313$ &             $\rho: 0.2494$ &             $\rho: 0.6061$ &             $\rho: 0.4567$ &             $\rho: 0.5011$ \\
#                  &          &       & wt-var &             $\rho: 0.4686$ &             $\rho: 0.4154$ &             $\rho: 0.5951$ &             $\rho: 0.5842$ &             $\rho: 0.7079$ \\
#                  &          &       & wt-var &           $\sigma: 0.4102$ &           $\sigma: 0.3114$ &           $\sigma: 0.5268$ &           $\sigma: 0.6024$ &           $\sigma: 0.7156$ \\
# \cline{1-9}
# \cline{2-9}
# \cline{3-9}
# \multirow{32}{*}{All except IBMArgQ} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &                       None &    $\rho: 0.401 \pm 0.075$ &    $\rho: 0.289 \pm 0.157$ &    $\rho: 0.499 \pm 0.129$ &    $\rho: 0.783 \pm 0.045$ \\
#                  &          &       & None &                       None &  $\sigma: 0.381 \pm 0.068$ &  $\sigma: 0.317 \pm 0.177$ &   $\sigma: 0.488 \pm 0.14$ &  $\sigma: 0.802 \pm 0.042$ \\
#                  &          &       & mean &           $\sigma: 0.2883$ &           $\sigma: 0.3739$ &           $\sigma: 0.5014$ &           $\sigma: 0.6455$ &            $\sigma: 0.714$ \\
#                  &          &       & mean &             $\rho: 0.3284$ &              $\rho: 0.412$ &             $\rho: 0.3924$ &              $\rho: 0.635$ &              $\rho: 0.721$ \\
#                  &          &       & var &             $\rho: 0.1292$ &             $\rho: 0.1251$ &             $\rho: 0.2788$ &             $\rho: 0.3715$ &             $\rho: 0.2615$ \\
#                  &          &       & var &           $\sigma: 0.0785$ &          $\sigma: -0.0084$ &           $\sigma: 0.3349$ &           $\sigma: 0.4781$ &           $\sigma: 0.1334$ \\
#                  &          &       & wt-var &              $\rho: 0.289$ &             $\rho: 0.3295$ &             $\rho: 0.3831$ &             $\rho: 0.5998$ &             $\rho: 0.6596$ \\
#                  &          &       & wt-var &           $\sigma: 0.2498$ &           $\sigma: 0.2886$ &           $\sigma: 0.4523$ &           $\sigma: 0.6026$ &           $\sigma: 0.5861$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &                       None &    $\rho: 0.396 \pm 0.082$ &    $\rho: 0.256 \pm 0.132$ &    $\rho: 0.492 \pm 0.134$ &    $\rho: 0.783 \pm 0.052$ \\
#                  &          &       & None &                       None &  $\sigma: 0.374 \pm 0.077$ &  $\sigma: 0.279 \pm 0.233$ &  $\sigma: 0.481 \pm 0.145$ &  $\sigma: 0.804 \pm 0.044$ \\
#                  &          &       & mean &             $\rho: 0.3371$ &              $\rho: 0.451$ &             $\rho: 0.3101$ &             $\rho: 0.6243$ &             $\rho: 0.7518$ \\
#                  &          &       & mean &           $\sigma: 0.3064$ &           $\sigma: 0.4177$ &           $\sigma: 0.3848$ &           $\sigma: 0.6336$ &           $\sigma: 0.7337$ \\
#                  &          &       & var &             $\rho: 0.0608$ &             $\rho: 0.0863$ &             $\rho: 0.0356$ &             $\rho: 0.3441$ &             $\rho: 0.3772$ \\
#                  &          &       & var &           $\sigma: 0.0208$ &           $\sigma: -0.081$ &           $\sigma: 0.3567$ &           $\sigma: 0.4071$ &           $\sigma: 0.3385$ \\
#                  &          &       & wt-var &            $\sigma: 0.248$ &           $\sigma: 0.3179$ &           $\sigma: 0.4062$ &           $\sigma: 0.5797$ &           $\sigma: 0.6734$ \\
#                  &          &       & wt-var &             $\rho: 0.2952$ &             $\rho: 0.3727$ &             $\rho: 0.3968$ &             $\rho: 0.5779$ &             $\rho: 0.7222$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &                       None &   $\sigma: 0.496 \pm 0.01$ &  $\sigma: 0.441 \pm 0.023$ &   $\sigma: 0.63 \pm 0.007$ &  $\sigma: 0.791 \pm 0.011$ \\
#                  &          &       & None &                       None &     $\rho: 0.516 \pm 0.01$ &    $\rho: 0.516 \pm 0.059$ &    $\rho: 0.658 \pm 0.007$ &    $\rho: 0.744 \pm 0.003$ \\
#                  &          &       & mean &             $\rho: 0.3835$ &               $\rho: 0.45$ &             $\rho: 0.5083$ &             $\rho: 0.6327$ &             $\rho: 0.7051$ \\
#                  &          &       & mean &           $\sigma: 0.3455$ &           $\sigma: 0.4106$ &           $\sigma: 0.5121$ &           $\sigma: 0.6144$ &           $\sigma: 0.7411$ \\
#                  &          &       & var &             $\rho: 0.2334$ &             $\rho: 0.2004$ &             $\rho: 0.5427$ &             $\rho: 0.5251$ &             $\rho: 0.5016$ \\
#                  &          &       & var &           $\sigma: 0.2155$ &           $\sigma: 0.1124$ &           $\sigma: 0.4689$ &           $\sigma: 0.5553$ &           $\sigma: 0.6661$ \\
#                  &          &       & wt-var &             $\rho: 0.3573$ &             $\rho: 0.3404$ &             $\rho: 0.5203$ &             $\rho: 0.5975$ &             $\rho: 0.6554$ \\
#                  &          &       & wt-var &            $\sigma: 0.306$ &           $\sigma: 0.2918$ &           $\sigma: 0.4604$ &           $\sigma: 0.5728$ &           $\sigma: 0.7044$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &                       None &  $\sigma: 0.515 \pm 0.012$ &  $\sigma: 0.435 \pm 0.055$ &   $\sigma: 0.65 \pm 0.008$ &  $\sigma: 0.811 \pm 0.011$ \\
#                  &          &       & None &                       None &    $\rho: 0.536 \pm 0.011$ &    $\rho: 0.573 \pm 0.061$ &    $\rho: 0.676 \pm 0.006$ &    $\rho: 0.762 \pm 0.003$ \\
#                  &          &       & mean &             $\rho: 0.3867$ &             $\rho: 0.4896$ &             $\rho: 0.5537$ &             $\rho: 0.6287$ &             $\rho: 0.7358$ \\
#                  &          &       & mean &             $\sigma: 0.36$ &           $\sigma: 0.4493$ &           $\sigma: 0.5932$ &           $\sigma: 0.6236$ &           $\sigma: 0.7783$ \\
#                  &          &       & var &            $\sigma: 0.224$ &           $\sigma: 0.1673$ &           $\sigma: 0.4846$ &           $\sigma: 0.4503$ &           $\sigma: 0.6287$ \\
#                  &          &       & var &             $\rho: 0.2285$ &             $\rho: 0.2496$ &             $\rho: 0.6548$ &             $\rho: 0.4358$ &             $\rho: 0.4559$ \\
#                  &          &       & wt-var &            $\sigma: 0.318$ &           $\sigma: 0.2833$ &           $\sigma: 0.5811$ &           $\sigma: 0.5878$ &           $\sigma: 0.7424$ \\
#                  &          &       & wt-var &             $\rho: 0.3585$ &             $\rho: 0.3738$ &              $\rho: 0.555$ &             $\rho: 0.5771$ &             $\rho: 0.6815$ \\
# \cline{1-9}
# \cline{2-9}
# \cline{3-9}
# \multirow{32}{*}{All except IBMRank} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.489 \pm 0.015$ &                       None &    $\rho: 0.407 \pm 0.102$ &    $\rho: 0.507 \pm 0.134$ &    $\rho: 0.788 \pm 0.051$ \\
#                  &          &       & None &  $\sigma: 0.434 \pm 0.009$ &                       None &  $\sigma: 0.508 \pm 0.163$ &  $\sigma: 0.495 \pm 0.147$ &  $\sigma: 0.795 \pm 0.048$ \\
#                  &          &       & mean &           $\sigma: 0.3664$ &           $\sigma: 0.3048$ &           $\sigma: 0.7102$ &            $\sigma: 0.639$ &            $\sigma: 0.808$ \\
#                  &          &       & mean &             $\rho: 0.4372$ &             $\rho: 0.3189$ &             $\rho: 0.3943$ &              $\rho: 0.632$ &             $\rho: 0.8086$ \\
#                  &          &       & var &           $\sigma: 0.2112$ &           $\sigma: 0.1126$ &           $\sigma: 0.6258$ &           $\sigma: 0.4887$ &           $\sigma: 0.5994$ \\
#                  &          &       & var &             $\rho: 0.2922$ &             $\rho: 0.1097$ &             $\rho: 0.2683$ &             $\rho: 0.4346$ &             $\rho: 0.6092$ \\
#                  &          &       & wt-var &           $\sigma: 0.3404$ &           $\sigma: 0.2599$ &            $\sigma: 0.704$ &           $\sigma: 0.6131$ &           $\sigma: 0.7398$ \\
#                  &          &       & wt-var &             $\rho: 0.4094$ &             $\rho: 0.2776$ &             $\rho: 0.3717$ &              $\rho: 0.609$ &             $\rho: 0.7648$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &  $\sigma: 0.423 \pm 0.008$ &                       None &  $\sigma: 0.489 \pm 0.189$ &  $\sigma: 0.483 \pm 0.158$ &  $\sigma: 0.796 \pm 0.046$ \\
#                  &          &       & None &    $\rho: 0.479 \pm 0.013$ &                       None &    $\rho: 0.406 \pm 0.093$ &    $\rho: 0.491 \pm 0.147$ &    $\rho: 0.789 \pm 0.052$ \\
#                  &          &       & mean &             $\rho: 0.4332$ &             $\rho: 0.3404$ &             $\rho: 0.4409$ &             $\rho: 0.5985$ &             $\rho: 0.8067$ \\
#                  &          &       & mean &           $\sigma: 0.3707$ &           $\sigma: 0.3317$ &           $\sigma: 0.7062$ &           $\sigma: 0.6086$ &           $\sigma: 0.8057$ \\
#                  &          &       & var &           $\sigma: 0.2272$ &           $\sigma: 0.1122$ &           $\sigma: 0.5913$ &            $\sigma: 0.358$ &           $\sigma: 0.6198$ \\
#                  &          &       & var &             $\rho: 0.2951$ &             $\rho: 0.1144$ &             $\rho: 0.2569$ &             $\rho: 0.3429$ &               $\rho: 0.54$ \\
#                  &          &       & wt-var &             $\rho: 0.4254$ &             $\rho: 0.3139$ &             $\rho: 0.4628$ &             $\rho: 0.5627$ &             $\rho: 0.7544$ \\
#                  &          &       & wt-var &           $\sigma: 0.3586$ &           $\sigma: 0.2932$ &           $\sigma: 0.7243$ &           $\sigma: 0.5669$ &           $\sigma: 0.7443$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &   $\sigma: 0.45 \pm 0.004$ &                       None &     $\sigma: 0.5 \pm 0.02$ &  $\sigma: 0.633 \pm 0.008$ &  $\sigma: 0.779 \pm 0.015$ \\
#                  &          &       & None &    $\rho: 0.505 \pm 0.004$ &                       None &    $\rho: 0.591 \pm 0.042$ &    $\rho: 0.659 \pm 0.007$ &     $\rho: 0.746 \pm 0.01$ \\
#                  &          &       & mean &           $\sigma: 0.3933$ &           $\sigma: 0.3321$ &           $\sigma: 0.5607$ &           $\sigma: 0.6016$ &           $\sigma: 0.7534$ \\
#                  &          &       & mean &              $\rho: 0.452$ &             $\rho: 0.3844$ &             $\rho: 0.5808$ &             $\rho: 0.6153$ &             $\rho: 0.7244$ \\
#                  &          &       & var &             $\rho: 0.2573$ &             $\rho: 0.2402$ &             $\rho: 0.3403$ &             $\rho: 0.4164$ &             $\rho: 0.4798$ \\
#                  &          &       & var &           $\sigma: 0.2741$ &           $\sigma: 0.1854$ &           $\sigma: 0.5051$ &           $\sigma: 0.5199$ &           $\sigma: 0.5564$ \\
#                  &          &       & wt-var &             $\rho: 0.4282$ &             $\rho: 0.3567$ &             $\rho: 0.5715$ &             $\rho: 0.6116$ &             $\rho: 0.6771$ \\
#                  &          &       & wt-var &           $\sigma: 0.3704$ &           $\sigma: 0.3079$ &           $\sigma: 0.5174$ &           $\sigma: 0.5944$ &           $\sigma: 0.6809$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &  $\sigma: 0.454 \pm 0.003$ &                       None &  $\sigma: 0.489 \pm 0.031$ &   $\sigma: 0.65 \pm 0.008$ &  $\sigma: 0.802 \pm 0.007$ \\
#                  &          &       & None &    $\rho: 0.507 \pm 0.003$ &                       None &    $\rho: 0.582 \pm 0.053$ &    $\rho: 0.673 \pm 0.009$ &    $\rho: 0.767 \pm 0.009$ \\
#                  &          &       & mean &             $\rho: 0.4711$ &             $\rho: 0.4212$ &             $\rho: 0.5602$ &             $\rho: 0.6063$ &             $\rho: 0.7461$ \\
#                  &          &       & mean &           $\sigma: 0.4123$ &           $\sigma: 0.3558$ &           $\sigma: 0.6029$ &           $\sigma: 0.6076$ &           $\sigma: 0.7767$ \\
#                  &          &       & var &             $\rho: 0.2969$ &             $\rho: 0.2611$ &             $\rho: 0.5025$ &             $\rho: 0.4085$ &             $\rho: 0.5166$ \\
#                  &          &       & var &           $\sigma: 0.2903$ &           $\sigma: 0.2094$ &           $\sigma: 0.5281$ &           $\sigma: 0.4298$ &           $\sigma: 0.6624$ \\
#                  &          &       & wt-var &             $\rho: 0.4409$ &             $\rho: 0.4077$ &             $\rho: 0.5674$ &             $\rho: 0.5545$ &             $\rho: 0.7135$ \\
#                  &          &       & wt-var &            $\sigma: 0.377$ &           $\sigma: 0.3163$ &            $\sigma: 0.567$ &           $\sigma: 0.5778$ &           $\sigma: 0.7628$ \\
# \cline{1-9}
# \cline{2-9}
# \cline{3-9}
# \multirow{32}{*}{All except SwanRank} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &     $\rho: 0.49 \pm 0.005$ &    $\rho: 0.402 \pm 0.063$ &    $\rho: 0.436 \pm 0.083$ &                       None &    $\rho: 0.789 \pm 0.052$ \\
#                  &          &       & None &  $\sigma: 0.433 \pm 0.007$ &  $\sigma: 0.386 \pm 0.057$ &  $\sigma: 0.526 \pm 0.187$ &                       None &  $\sigma: 0.805 \pm 0.052$ \\
#                  &          &       & mean &             $\rho: 0.4696$ &             $\rho: 0.3432$ &             $\rho: 0.3537$ &             $\rho: 0.5142$ &             $\rho: 0.7343$ \\
#                  &          &       & mean &           $\sigma: 0.4161$ &            $\sigma: 0.314$ &           $\sigma: 0.5046$ &           $\sigma: 0.5259$ &           $\sigma: 0.7638$ \\
#                  &          &       & var &             $\rho: 0.2919$ &             $\rho: 0.1571$ &             $\rho: 0.2404$ &             $\rho: 0.4039$ &             $\rho: 0.3665$ \\
#                  &          &       & var &           $\sigma: 0.2438$ &           $\sigma: 0.1624$ &           $\sigma: 0.3717$ &           $\sigma: 0.4742$ &           $\sigma: 0.3095$ \\
#                  &          &       & wt-var &             $\rho: 0.4463$ &             $\rho: 0.3147$ &             $\rho: 0.3048$ &              $\rho: 0.524$ &             $\rho: 0.6743$ \\
#                  &          &       & wt-var &           $\sigma: 0.3871$ &           $\sigma: 0.2858$ &           $\sigma: 0.4394$ &           $\sigma: 0.5296$ &           $\sigma: 0.6896$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &    $\rho: 0.477 \pm 0.006$ &    $\rho: 0.329 \pm 0.095$ &    $\rho: 0.393 \pm 0.099$ &                       None &    $\rho: 0.781 \pm 0.056$ \\
#                  &          &       & None &  $\sigma: 0.427 \pm 0.007$ &  $\sigma: 0.306 \pm 0.099$ &  $\sigma: 0.444 \pm 0.237$ &                       None &  $\sigma: 0.795 \pm 0.038$ \\
#                  &          &       & mean &            $\sigma: 0.415$ &           $\sigma: 0.3149$ &           $\sigma: 0.4862$ &           $\sigma: 0.4662$ &           $\sigma: 0.7835$ \\
#                  &          &       & mean &             $\rho: 0.4653$ &             $\rho: 0.3315$ &             $\rho: 0.3463$ &             $\rho: 0.4548$ &             $\rho: 0.7627$ \\
#                  &          &       & var &            $\sigma: 0.198$ &           $\sigma: 0.1099$ &           $\sigma: 0.3263$ &           $\sigma: 0.2982$ &           $\sigma: 0.4475$ \\
#                  &          &       & var &             $\rho: 0.2421$ &             $\rho: 0.1566$ &              $\rho: 0.111$ &             $\rho: 0.2862$ &             $\rho: 0.3729$ \\
#                  &          &       & wt-var &              $\rho: 0.448$ &             $\rho: 0.3074$ &             $\rho: 0.3401$ &             $\rho: 0.4596$ &             $\rho: 0.7214$ \\
#                  &          &       & wt-var &           $\sigma: 0.3936$ &           $\sigma: 0.2689$ &           $\sigma: 0.4376$ &           $\sigma: 0.4578$ &           $\sigma: 0.7393$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.509 \pm 0.002$ &     $\rho: 0.514 \pm 0.01$ &    $\rho: 0.559 \pm 0.057$ &                       None &    $\rho: 0.574 \pm 0.015$ \\
#                  &          &       & None &  $\sigma: 0.454 \pm 0.003$ &   $\sigma: 0.493 \pm 0.01$ &  $\sigma: 0.495 \pm 0.027$ &                       None &  $\sigma: 0.621 \pm 0.016$ \\
#                  &          &       & mean &             $\rho: 0.4887$ &             $\rho: 0.4775$ &             $\rho: 0.4779$ &             $\rho: 0.4693$ &             $\rho: 0.7028$ \\
#                  &          &       & mean &           $\sigma: 0.4433$ &           $\sigma: 0.4426$ &           $\sigma: 0.5072$ &           $\sigma: 0.5083$ &           $\sigma: 0.7274$ \\
#                  &          &       & var &             $\rho: 0.3202$ &             $\rho: 0.2584$ &             $\rho: 0.5874$ &             $\rho: 0.3933$ &             $\rho: 0.3938$ \\
#                  &          &       & var &           $\sigma: 0.3145$ &           $\sigma: 0.1853$ &            $\sigma: 0.442$ &           $\sigma: 0.4455$ &           $\sigma: 0.5764$ \\
#                  &          &       & wt-var &             $\rho: 0.4558$ &             $\rho: 0.4488$ &             $\rho: 0.4926$ &              $\rho: 0.478$ &             $\rho: 0.6202$ \\
#                  &          &       & wt-var &           $\sigma: 0.4108$ &           $\sigma: 0.4031$ &           $\sigma: 0.5731$ &           $\sigma: 0.5153$ &           $\sigma: 0.6014$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &  $\sigma: 0.461 \pm 0.003$ &  $\sigma: 0.498 \pm 0.004$ &   $\sigma: 0.61 \pm 0.037$ &                       None &  $\sigma: 0.644 \pm 0.015$ \\
#                  &          &       & None &    $\rho: 0.514 \pm 0.004$ &    $\rho: 0.529 \pm 0.008$ &    $\rho: 0.577 \pm 0.069$ &                       None &    $\rho: 0.578 \pm 0.019$ \\
#                  &          &       & mean &            $\sigma: 0.458$ &           $\sigma: 0.4572$ &           $\sigma: 0.5652$ &           $\sigma: 0.4646$ &           $\sigma: 0.7554$ \\
#                  &          &       & mean &             $\rho: 0.5066$ &             $\rho: 0.5031$ &             $\rho: 0.5021$ &             $\rho: 0.4058$ &             $\rho: 0.7292$ \\
#                  &          &       & var &            $\sigma: 0.347$ &            $\sigma: 0.241$ &           $\sigma: 0.4762$ &           $\sigma: 0.3002$ &           $\sigma: 0.6927$ \\
#                  &          &       & var &             $\rho: 0.3642$ &             $\rho: 0.3046$ &             $\rho: 0.4389$ &             $\rho: 0.2994$ &             $\rho: 0.5646$ \\
#                  &          &       & wt-var &           $\sigma: 0.4232$ &           $\sigma: 0.4263$ &           $\sigma: 0.6033$ &           $\sigma: 0.3995$ &           $\sigma: 0.6954$ \\
#                  &          &       & wt-var &             $\rho: 0.4828$ &             $\rho: 0.4855$ &             $\rho: 0.5347$ &             $\rho: 0.3454$ &             $\rho: 0.7101$ \\
# \cline{1-9}
# \cline{2-9}
# \cline{3-9}
# \multirow{32}{*}{All except UKPConvArgRank} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.492 \pm 0.014$ &    $\rho: 0.441 \pm 0.066$ &                       None &    $\rho: 0.504 \pm 0.135$ &    $\rho: 0.785 \pm 0.051$ \\
#                  &          &       & None &   $\sigma: 0.436 \pm 0.01$ &  $\sigma: 0.421 \pm 0.058$ &                       None &  $\sigma: 0.492 \pm 0.148$ &  $\sigma: 0.792 \pm 0.052$ \\
#                  &          &       & mean &             $\rho: 0.4536$ &             $\rho: 0.3627$ &              $\rho: 0.395$ &             $\rho: 0.5961$ &             $\rho: 0.7936$ \\
#                  &          &       & mean &           $\sigma: 0.3964$ &           $\sigma: 0.3578$ &           $\sigma: 0.6781$ &           $\sigma: 0.6119$ &           $\sigma: 0.7923$ \\
#                  &          &       & var &             $\rho: 0.3521$ &             $\rho: 0.2916$ &             $\rho: 0.2957$ &             $\rho: 0.2798$ &             $\rho: 0.6219$ \\
#                  &          &       & var &           $\sigma: 0.3626$ &           $\sigma: 0.2969$ &           $\sigma: 0.5523$ &           $\sigma: 0.3023$ &           $\sigma: 0.5983$ \\
#                  &          &       & wt-var &             $\rho: 0.4483$ &             $\rho: 0.3544$ &             $\rho: 0.3706$ &             $\rho: 0.5565$ &             $\rho: 0.7839$ \\
#                  &          &       & wt-var &           $\sigma: 0.4002$ &           $\sigma: 0.3459$ &           $\sigma: 0.6581$ &           $\sigma: 0.5707$ &           $\sigma: 0.7635$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &  $\sigma: 0.427 \pm 0.007$ &  $\sigma: 0.358 \pm 0.078$ &                       None &  $\sigma: 0.469 \pm 0.144$ &  $\sigma: 0.807 \pm 0.045$ \\
#                  &          &       & None &    $\rho: 0.482 \pm 0.009$ &    $\rho: 0.376 \pm 0.082$ &                       None &    $\rho: 0.481 \pm 0.136$ &    $\rho: 0.793 \pm 0.057$ \\
#                  &          &       & mean &           $\sigma: 0.4047$ &           $\sigma: 0.3059$ &           $\sigma: 0.4845$ &           $\sigma: 0.5536$ &           $\sigma: 0.7668$ \\
#                  &          &       & mean &             $\rho: 0.4554$ &             $\rho: 0.3235$ &             $\rho: 0.3466$ &             $\rho: 0.5283$ &             $\rho: 0.7439$ \\
#                  &          &       & var &           $\sigma: 0.3295$ &           $\sigma: 0.2163$ &            $\sigma: 0.359$ &           $\sigma: 0.1918$ &           $\sigma: 0.5644$ \\
#                  &          &       & var &             $\rho: 0.3523$ &             $\rho: 0.2093$ &             $\rho: 0.2538$ &             $\rho: 0.2122$ &             $\rho: 0.5367$ \\
#                  &          &       & wt-var &           $\sigma: 0.4033$ &           $\sigma: 0.2924$ &            $\sigma: 0.493$ &           $\sigma: 0.5033$ &            $\sigma: 0.755$ \\
#                  &          &       & wt-var &              $\rho: 0.448$ &             $\rho: 0.3032$ &             $\rho: 0.3305$ &             $\rho: 0.4918$ &             $\rho: 0.7357$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &    $\rho: 0.509 \pm 0.002$ &    $\rho: 0.519 \pm 0.008$ &                       None &    $\rho: 0.655 \pm 0.006$ &    $\rho: 0.529 \pm 0.027$ \\
#                  &          &       & None &  $\sigma: 0.455 \pm 0.002$ &  $\sigma: 0.502 \pm 0.009$ &                       None &  $\sigma: 0.625 \pm 0.007$ &  $\sigma: 0.564 \pm 0.032$ \\
#                  &          &       & mean &               $\rho: 0.48$ &             $\rho: 0.4658$ &             $\rho: 0.5404$ &              $\rho: 0.592$ &             $\rho: 0.7131$ \\
#                  &          &       & mean &             $\sigma: 0.43$ &           $\sigma: 0.4277$ &           $\sigma: 0.5208$ &           $\sigma: 0.5966$ &           $\sigma: 0.7379$ \\
#                  &          &       & var &             $\rho: 0.3373$ &             $\rho: 0.4053$ &             $\rho: 0.3706$ &             $\rho: 0.3451$ &             $\rho: 0.4761$ \\
#                  &          &       & var &           $\sigma: 0.3475$ &           $\sigma: 0.4322$ &           $\sigma: 0.4131$ &           $\sigma: 0.3601$ &           $\sigma: 0.4887$ \\
#                  &          &       & wt-var &           $\sigma: 0.4215$ &           $\sigma: 0.4158$ &           $\sigma: 0.5251$ &           $\sigma: 0.5841$ &           $\sigma: 0.7047$ \\
#                  &          &       & wt-var &             $\rho: 0.4625$ &             $\rho: 0.4415$ &              $\rho: 0.514$ &             $\rho: 0.5671$ &             $\rho: 0.6769$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &     $\rho: 0.51 \pm 0.004$ &    $\rho: 0.502 \pm 0.006$ &                       None &    $\rho: 0.673 \pm 0.006$ &    $\rho: 0.504 \pm 0.016$ \\
#                  &          &       & None &  $\sigma: 0.458 \pm 0.003$ &  $\sigma: 0.486 \pm 0.009$ &                       None &  $\sigma: 0.648 \pm 0.006$ &   $\sigma: 0.58 \pm 0.023$ \\
#                  &          &       & mean &             $\rho: 0.4996$ &             $\rho: 0.4911$ &             $\rho: 0.5345$ &             $\rho: 0.5931$ &             $\rho: 0.7226$ \\
#                  &          &       & mean &           $\sigma: 0.4543$ &           $\sigma: 0.4562$ &           $\sigma: 0.5733$ &           $\sigma: 0.6121$ &           $\sigma: 0.7467$ \\
#                  &          &       & var &            $\sigma: 0.333$ &           $\sigma: 0.2482$ &           $\sigma: 0.4148$ &           $\sigma: 0.4064$ &           $\sigma: 0.3923$ \\
#                  &          &       & var &              $\rho: 0.355$ &             $\rho: 0.2945$ &             $\rho: 0.3776$ &             $\rho: 0.4107$ &             $\rho: 0.4887$ \\
#                  &          &       & wt-var &           $\sigma: 0.4477$ &           $\sigma: 0.4605$ &           $\sigma: 0.5881$ &           $\sigma: 0.5926$ &            $\sigma: 0.729$ \\
#                  &          &       & wt-var &             $\rho: 0.4903$ &             $\rho: 0.4931$ &               $\rho: 0.55$ &             $\rho: 0.5635$ &             $\rho: 0.7141$ \\
# \cline{1-9}
# \cline{2-9}
# \cline{3-9}
# \multirow{32}{*}{All except Webis} & \multirow{16}{*}{cross-topic} & \multirow{8}{*}{no-topic} & None &  $\sigma: 0.434 \pm 0.008$ &  $\sigma: 0.419 \pm 0.057$ &  $\sigma: 0.424 \pm 0.143$ &  $\sigma: 0.488 \pm 0.146$ &                       None \\
#                  &          &       & None &     $\rho: 0.49 \pm 0.012$ &     $\rho: 0.44 \pm 0.064$ &    $\rho: 0.337 \pm 0.091$ &    $\rho: 0.499 \pm 0.132$ &                       None \\
#                  &          &       & mean &           $\sigma: 0.3964$ &           $\sigma: 0.4814$ &           $\sigma: 0.4503$ &           $\sigma: 0.6035$ &           $\sigma: 0.1968$ \\
#                  &          &       & mean &             $\rho: 0.4492$ &             $\rho: 0.5076$ &             $\rho: 0.2967$ &             $\rho: 0.5941$ &             $\rho: 0.2074$ \\
#                  &          &       & var &           $\sigma: 0.2078$ &           $\sigma: 0.1735$ &           $\sigma: 0.4672$ &           $\sigma: 0.4392$ &           $\sigma: 0.2738$ \\
#                  &          &       & var &             $\rho: 0.2164$ &             $\rho: 0.2327$ &             $\rho: 0.1977$ &             $\rho: 0.3604$ &             $\rho: 0.1792$ \\
#                  &          &       & wt-var &             $\rho: 0.4307$ &             $\rho: 0.4793$ &             $\rho: 0.3001$ &             $\rho: 0.5852$ &             $\rho: 0.2184$ \\
#                  &          &       & wt-var &           $\sigma: 0.3703$ &           $\sigma: 0.4504$ &           $\sigma: 0.4468$ &           $\sigma: 0.5879$ &           $\sigma: 0.1995$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &    $\rho: 0.478 \pm 0.011$ &    $\rho: 0.423 \pm 0.079$ &    $\rho: 0.285 \pm 0.113$ &    $\rho: 0.485 \pm 0.141$ &                       None \\
#                  &          &       & None &  $\sigma: 0.422 \pm 0.006$ &  $\sigma: 0.403 \pm 0.072$ &  $\sigma: 0.341 \pm 0.186$ &  $\sigma: 0.475 \pm 0.154$ &                       None \\
#                  &          &       & mean &              $\rho: 0.446$ &             $\rho: 0.5119$ &             $\rho: 0.2162$ &             $\rho: 0.5985$ &             $\rho: 0.2279$ \\
#                  &          &       & mean &           $\sigma: 0.3977$ &           $\sigma: 0.4843$ &           $\sigma: 0.3315$ &           $\sigma: 0.6127$ &           $\sigma: 0.2152$ \\
#                  &          &       & var &             $\rho: 0.2156$ &             $\rho: 0.1957$ &             $\rho: 0.0959$ &             $\rho: 0.3637$ &             $\rho: 0.1256$ \\
#                  &          &       & var &           $\sigma: 0.2155$ &           $\sigma: 0.2442$ &           $\sigma: 0.3023$ &           $\sigma: 0.4228$ &           $\sigma: 0.2666$ \\
#                  &          &       & wt-var &             $\rho: 0.4275$ &             $\rho: 0.4766$ &              $\rho: 0.218$ &             $\rho: 0.5608$ &             $\rho: 0.2438$ \\
#                  &          &       & wt-var &           $\sigma: 0.3729$ &           $\sigma: 0.4419$ &           $\sigma: 0.3211$ &           $\sigma: 0.5678$ &           $\sigma: 0.2129$ \\
# \cline{2-9}
# \cline{3-9}
#                  & \multirow{16}{*}{in-topic} & \multirow{8}{*}{no-topic} & None &  $\sigma: 0.455 \pm 0.005$ &  $\sigma: 0.477 \pm 0.009$ &  $\sigma: 0.589 \pm 0.044$ &  $\sigma: 0.617 \pm 0.009$ &                       None \\
#                  &          &       & None &    $\rho: 0.508 \pm 0.004$ &    $\rho: 0.496 \pm 0.006$ &    $\rho: 0.647 \pm 0.048$ &    $\rho: 0.647 \pm 0.012$ &                       None \\
#                  &          &       & mean &             $\rho: 0.4878$ &             $\rho: 0.4653$ &             $\rho: 0.5473$ &             $\rho: 0.6254$ &             $\rho: 0.4122$ \\
#                  &          &       & mean &           $\sigma: 0.4369$ &           $\sigma: 0.4402$ &           $\sigma: 0.5593$ &           $\sigma: 0.6049$ &           $\sigma: 0.3781$ \\
#                  &          &       & var &              $\rho: 0.316$ &             $\rho: 0.2512$ &             $\rho: 0.3722$ &             $\rho: 0.4344$ &             $\rho: 0.3995$ \\
#                  &          &       & var &           $\sigma: 0.3035$ &           $\sigma: 0.1681$ &            $\sigma: 0.487$ &           $\sigma: 0.4979$ &           $\sigma: 0.5479$ \\
#                  &          &       & wt-var &             $\rho: 0.4701$ &             $\rho: 0.4221$ &             $\rho: 0.5627$ &             $\rho: 0.6314$ &             $\rho: 0.4384$ \\
#                  &          &       & wt-var &           $\sigma: 0.4067$ &           $\sigma: 0.3752$ &           $\sigma: 0.5939$ &           $\sigma: 0.6119$ &           $\sigma: 0.4132$ \\
# \cline{3-9}
#                  &          & \multirow{8}{*}{topic} & None &    $\rho: 0.506 \pm 0.001$ &    $\rho: 0.485 \pm 0.007$ &    $\rho: 0.422 \pm 0.065$ &    $\rho: 0.669 \pm 0.009$ &                       None \\
#                  &          &       & None &  $\sigma: 0.452 \pm 0.003$ &  $\sigma: 0.465 \pm 0.004$ &  $\sigma: 0.389 \pm 0.041$ &   $\sigma: 0.64 \pm 0.006$ &                       None \\
#                  &          &       & mean &             $\rho: 0.5029$ &             $\rho: 0.5127$ &             $\rho: 0.4915$ &             $\rho: 0.6349$ &             $\rho: 0.3795$ \\
#                  &          &       & mean &            $\sigma: 0.452$ &           $\sigma: 0.4806$ &           $\sigma: 0.6198$ &           $\sigma: 0.6225$ &           $\sigma: 0.3953$ \\
#                  &          &       & var &           $\sigma: 0.3191$ &           $\sigma: 0.2559$ &            $\sigma: 0.408$ &           $\sigma: 0.4175$ &           $\sigma: 0.4955$ \\
#                  &          &       & var &             $\rho: 0.2691$ &             $\rho: 0.2964$ &             $\rho: 0.4718$ &             $\rho: 0.3704$ &             $\rho: 0.1571$ \\
#                  &          &       & wt-var &             $\rho: 0.4774$ &             $\rho: 0.4562$ &             $\rho: 0.4456$ &             $\rho: 0.6196$ &             $\rho: 0.3545$ \\
#                  &          &       & wt-var &           $\sigma: 0.4261$ &            $\sigma: 0.415$ &           $\sigma: 0.5847$ &           $\sigma: 0.6077$ &           $\sigma: 0.3963$ \\
# \bottomrule
# \end{tabular}
# \end{table}
