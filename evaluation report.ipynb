# %%
import numpy as np
import pandas as pd
import ast
from scipy.stats import pearsonr, spearmanr
from statistics import mean, stdev
from typing import List

# %% [markdown]
# ### Evaluation for Task 1

# %%
gretz_eval = pd.read_csv("task1/gretz/eval_results.csv", sep=",")
swanson_eval = pd.read_csv("task1/swanson/eval_results.csv", sep=",")
ukprank_eval = pd.read_csv("task1/ukprank/eval_results.csv", sep=",")
toledo_eval = pd.read_csv("task1/toledo/eval_results.csv", sep=",")

# %%
toledo_eval_agg = toledo_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
gretz_eval_agg = gretz_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
swanson_eval_agg = swanson_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
ukprank_eval_agg = ukprank_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})

# %%
toledo_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.355605  0.010689  0.325372
# 1                 test/swanson_test.txt  0.328874  0.018282  0.326629
# 2                  test/toledo_test.txt  0.399626  0.040046  0.383145
# 3                 test/ukprank_test.txt  0.504112  0.016553  0.661100
#
#
#         std
# 0  0.011009
# 1  0.021130
# 2  0.059058
# 3  0.025972

# %%
gretz_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.490441  0.040451  0.452176
# 1                 test/swanson_test.txt  0.520899  0.015442  0.532662
# 2                  test/toledo_test.txt  0.405762  0.055152  0.371319
# 3                 test/ukprank_test.txt  0.543245  0.042314  0.657114
#
#
#         std
# 0  0.032352
# 1  0.014429
# 2  0.069453
# 3  0.139051

# %%
swanson_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.162835  0.013926  0.129164
# 1                 test/swanson_test.txt  0.613879  0.005188  0.607331
# 2                  test/toledo_test.txt  0.252555  0.050107  0.244065
# 3                 test/ukprank_test.txt  0.471807  0.050491  0.673433
#
#
#         std
# 0  0.010661
# 1  0.005860
# 2  0.053047
# 3  0.048046

# %%
ukprank_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.237016  0.026899  0.156693
# 1                 test/swanson_test.txt  0.430654  0.037745  0.448086
# 2                  test/toledo_test.txt  0.156355  0.049900  0.176703
# 3                 test/ukprank_test.txt  0.560050  0.033486  0.813087
#
#
#         std
# 0  0.027466
# 1  0.029510
# 2  0.037519
# 3  0.027422

# %% [markdown]
# ### Evaluation for Task 2:

# %%
loo_gretz_eval = pd.read_csv("task2/loo_gretz/eval_results.csv", sep=",")
loo_swanson_eval = pd.read_csv("task2/loo_swanson/eval_results.csv", sep=",")
loo_ukprank_eval = pd.read_csv("task2/loo_ukprank/eval_results.csv", sep=",")
loo_toledo_eval = pd.read_csv("task2/loo_toledo/eval_results.csv", sep=",")

# %%
loo_toledo_eval_agg = loo_toledo_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
loo_gretz_eval_agg = loo_gretz_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
loo_swanson_eval_agg = loo_swanson_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})
loo_ukprank_eval_agg = loo_ukprank_eval.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})

# %%
loo_toledo_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.521768  0.002928  0.479052
# 1                 test/swanson_test.txt  0.631231  0.002607  0.624833
# 2                  test/toledo_test.txt  0.353789  0.007608  0.348808
# 3                 test/ukprank_test.txt  0.507627  0.014990  0.734642
#
#
#         std
# 0  0.002002
# 1  0.001208
# 2  0.011154
# 3  0.002459

# %%
loo_gretz_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.213421  0.009275  0.154685
# 1                 test/swanson_test.txt  0.565460  0.033337  0.555177
# 2                  test/toledo_test.txt  0.342237  0.032980  0.335269
# 3                 test/ukprank_test.txt  0.383064  0.011186  0.549041
#
#
#         std
# 0  0.011652
# 1  0.037247
# 2  0.017364
# 3  0.029139

# %%
loo_swanson_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.469780  0.001756  0.424756
# 1                 test/swanson_test.txt  0.457463  0.029629  0.463017
# 2                  test/toledo_test.txt  0.387890  0.030248  0.379509
# 3                 test/ukprank_test.txt  0.268454  0.004148  0.509250
#
#
#         std
# 0  0.004455
# 1  0.018846
# 2  0.043748
# 3  0.010519

# %%
loo_ukprank_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.491318  0.000963  0.439769
# 1                 test/swanson_test.txt  0.648445  0.006183  0.640199
# 2                  test/toledo_test.txt  0.422375  0.005779  0.388530
# 3                 test/ukprank_test.txt  0.490680  0.007595  0.683131
#
#
#         std
# 0  0.000723
# 1  0.007161
# 2  0.004429
# 3  0.026814

# %% [markdown]
# ### Evaluation for Task 3:

# %%
eval_task3 = pd.read_csv("task3/all/eval_results.csv", sep=",")
task3_eval_agg = eval_task3.groupby(["test_file"], as_index=False).agg(
                      {'pearson':['mean','std'], 'spearman':['mean','std']})

# %%
task3_eval_agg
# Out:
#                               test_file   pearson            spearman  \
#                                              mean       std      mean
# 0  test/gretz_test_no_common_topics.txt  0.487788  0.002569  0.431096
# 1                 test/swanson_test.txt  0.638907  0.002686  0.628741
# 2                  test/toledo_test.txt  0.397499  0.002045  0.383502
# 3                 test/ukprank_test.txt  0.271300  0.012691  0.479644
#
#
#         std
# 0  0.002577
# 1  0.000046
# 2  0.004549
# 3  0.022216

# %% [markdown]
# ## Handling Inferences:

# %%
data1 = pd.read_csv("infer_logits1223.csv")

# %%
def average_logits(df, col_name, var_method = False):
    
  data_set_logits = []
  data_set_var_logits = []
  for i in range(len(data1)):

    dataset_logits = ast.literal_eval(data1[col_name][i])
    data_set_logits.append(dataset_logits)
  
  data_set_mean_logits = list(map(mean, zip(*data_set_logits)))
  data_set_mean_logits = list(map(
      lambda x: round(x, ndigits=6), data_set_mean_logits))

  if var_method:
    data_set_var_logits = list(map(stdev, zip(*data_set_logits)))
    data_set_var_logits = list(map(
        lambda x: round(x, ndigits=6), data_set_var_logits))
  
  return data_set_mean_logits, data_set_var_logits


def cal_eval_metrics(data1: pd.DataFrame, logits: List):

  datasets = ast.literal_eval(data1["orig_ds"][0])
  labels = ast.literal_eval(data1["labels"][0])
  labels = list(map(lambda x: round(x, ndigits=6), labels))

  assert len(datasets) == len(labels)
  assert len(logits) == len(labels)

  unlabeled_pearson = round(pearsonr(logits, labels)[0], 4)
  unlabeled_spearman = round(spearmanr(labels, logits)[0], 4)

  print("Unknown pearson:", unlabeled_pearson)
  print("Unknown spearman:", unlabeled_spearman)

  # group values by the datasets to help calculate the pearson values by dataset.
  data2 = pd.DataFrame(np.column_stack([datasets, labels, logits]), 
                       columns=["datasets", "labels", "logits"])
  
  data3 = data2.groupby(['datasets'])

  for i in list(data4.groups.keys()):
    
    print(i)
    data_gp = data3.get_group(i)
    logits = [float(i) for i in data_gp["logits"]]
    labels = [float(i) for i in data_gp["labels"]]
    pearson_value = round(pearsonr(logits, labels)[0], ndigits=4)
    spearman_value = round(spearmanr(logits, labels)[0], ndigits=4)

    print("pearson:", pearson_value)
    print("spearman:", spearman_value)

  return None

# %%
randomized_eval
# Out:
#                           model_id  seed  avg_train_loss  avg_val_loss  \
# 0      STLAS_only_gretz_randomized  5001        0.017910      0.029394
# 1      STLAS_only_gretz_randomized  2915        0.018232      0.031532
# 2      STLAS_only_gretz_randomized  2856        0.017464      0.029218
# 3      STLAS_only_gretz_randomized  3027        0.019517      0.030993
# 4      STLAS_only_gretz_randomized    68        0.018718      0.031879
# 5      STLAS_only_gretz_randomized  9735        0.018686      0.029655
# 6      STLAS_only_gretz_randomized  8267        0.018625      0.030189
# 7      STLAS_only_gretz_randomized  7828        0.018183      0.030474
# 8      STLAS_only_gretz_randomized  5132        0.019446      0.030905
# 9      STLAS_only_gretz_randomized  9667        0.019296      0.029931
# 10    STLAS_only_toledo_randomized  6914        0.024432      0.037950
# 11    STLAS_only_toledo_randomized  6213        0.022287      0.038476
# ...

# %% [markdown]
# ## Randomization Evaluation:

# %%
randomized_eval = pd.read_csv("Tasks/randomized_results/randomized_results.csv", sep=",")
randomized_eval1 = pd.read_csv("Tasks/randomized_results/randomized_results1.csv", sep=",")

# %%
randomized_eval_agg = randomized_eval.groupby(["model_id"], as_index=False).agg(
                      {'gretz_pearson':['mean','std'], 'toledo_pearson':['mean','std'], 'swanson_pearson':['mean','std'], 'ukp_pearson':['mean','std'], 'avg_test_loss':['mean']})
randomized_eval_agg1 = randomized_eval1.groupby(["model_id"], as_index=False).agg(
                      {'gretz_pearson':['mean','std'], 'toledo_pearson':['mean','std'], 'swanson_pearson':['mean','std'], 'ukp_pearson':['mean','std'], 'avg_test_loss':['mean']})

# %%
randomized_eval_agg
# Out:
#                          model_id gretz_pearson           toledo_pearson  \
#                                            mean       std           mean
# 0      MTLAS_LOO_gretz_randomized      0.000000  0.000000       0.367182
# 1    MTLAS_LOO_swanson_randomized      0.497159  0.011250       0.380725
# 2     MTLAS_LOO_toledo_randomized      0.485949  0.017417       0.000000
# 3        MTLAS_LOO_ukp_randomized      0.490178  0.016361       0.342832
# 4                MTLAS_randomized      0.487424  0.020851       0.372744
# 5            MTLAS_randomized_all      0.477936  0.027132       0.319090
# 6           MTLAS_randomized_mean      0.451063       NaN       0.321763
# 7      STLAS_LOO_gretz_randomized      0.210881  0.035656       0.197788
# 8    STLAS_LOO_swanson_randomized      0.379929  0.042330       0.205424
# 9     STLAS_LOO_toledo_randomized      0.445330  0.019697       0.323793
# 10       STLAS_LOO_ukp_randomized      0.409440  0.027937       0.338668
# ...

# %%
randomized_eval_agg1
# Out:
#                                model_id gretz_pearson            \
#                                                  mean       std
# 0           MTLAS_randomized_source_all      0.489907  0.020940
# 1            MTLAS_randomized_topic_all      0.491594  0.013426
# 2     STLAS_only_gretz_randomized_topic      0.481339  0.012700
# 3   STLAS_only_swanson_randomized_topic      0.082425  0.062808
# 4    STLAS_only_toledo_randomized_topic      0.389674  0.036650
# 5       STLAS_only_ukp_randomized_topic      0.030831  0.030685
# 6      STLAS_randomized_LOO_gretz_topic      0.465420  0.031726
# 7    STLAS_randomized_LOO_swanson_topic      0.465837  0.020225
# 8     STLAS_randomized_LOO_toledo_topic      0.475487  0.021799
# 9        STLAS_randomized_LOO_ukp_topic      0.466423  0.024591
# 10              STLAS_randomized_source      0.485525  0.019507
#
#    toledo_pearson           swanson_pearson           ukp_pearson            \
# ...

# %%
import os, json
import pandas as pd

# this finds our json files
path_to_json = 'json/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# here I define my pandas Dataframe with the columns I want to get from the json
jsons_data = pd.DataFrame(columns=['task_name', 'mean_gretz_pearson', 'mean_toledo_pearson', 'mean_swanson_pearson',
                                   'var_gretz_pearson', 'mean_ukp_pearson', 'var_toledo_pearson',
                                   'var_swanson_pearson','var_ukp_pearson',
                                   'wt-var_gretz_pearson', 'wt-var_toledo_pearson', 'wt-var_swanson_pearson',
                                   'wt-var_ukp_pearson'])

# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        country = json_text['features'][0]['properties']['country']
        city = json_text['features'][0]['properties']['name']
        lonlat = json_text['features'][0]['geometry']['coordinates']
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [country, city, lonlat]

# now that we have the pertinent json data in our DataFrame let's look at it
print(jsons_data)
